# %% [markdown]
# <a href="https://colab.research.google.com/github/Utpal-Mishra/Zerve/blob/main/ZerveRelatedProducts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# DATA SOURCE: https://oec.world/en/profile/hs92/steel-bars?countryComparisonFlowSelector=Imports&countryComparisonMeasureSelector=Growth%20Rate&countryComparisonRankSelector=Top&cumulativeMarketShareSelected=share&redirect=true&yearSelector2=tradeYear2&yearSelector4=tradeYear1

# %% [markdown]
# ### Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import plotly.express as px
import plotly.graph_objects as go
from datetime import datetime as dt

# %% [markdown]
# ### Import Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## **Import Dependencies**

# %% [markdown]
# ### Import File

# %%
import pandas as pd
path = '/content/drive/MyDrive/Jobs/Zerve/Related-Products.csv'
data = pd.read_csv(path)
print("Data Shape: ", data.shape)
data
# Out:
# Data Shape:  (1217, 8)
#       Section ID            Section  ...   Trade Value      id
# 0              1    Animal Products  ...  3.316602e+09   10101
# 1              1    Animal Products  ...  9.050742e+09   10102
# 2              1    Animal Products  ...  4.180847e+09   10103
# 3              1    Animal Products  ...  1.732222e+09   10104
# 4              1    Animal Products  ...  3.200487e+09   10105
# ...          ...                ...  ...           ...     ...
# 1212          21  Arts and Antiques  ...  4.946755e+08  219702
# 1213          21  Arts and Antiques  ...  4.184434e+09  219703
# 1214          21  Arts and Antiques  ...  1.308665e+08  219704
# 1215          21  Arts and Antiques  ...  1.489845e+09  219705
# 1216          21  Arts and Antiques  ...  3.461361e+09  219706
#
# [1217 rows x 8 columns]

# %%
data.columns
# Out:
# Index(['Section ID', 'Section', 'HS2 ID', 'HS2', 'HS4 ID', 'HS4',
#        'Trade Value', 'id'],
#       dtype='object')

# %% [markdown]
# ## **Exploratory Data Analysis**

# %% [markdown]
# ### Check Null Values

# %%
if data.isna().sum().sum() != 0:
  print("EMPTY VALUES EXIST IN THE DATA\n\nFollowing is a list of feature variable with their respective null values count:", data.isna().sum())

# %% [markdown]
# # **Visualization**

# %% [markdown]
# ## **GROUP BY SECTION**

# %%
dt = data[["Section", 'Trade Value']]
dt = dt.groupby(['Section']).sum().reset_index()
dt
# Out:
#                              Section   Trade Value
# 0                       Animal Hides  1.041829e+11
# 1                    Animal Products  3.787023e+11
# 2   Animal and Vegetable Bi-Products  1.004449e+11
# 3                  Arts and Antiques  2.699257e+10
# 4                  Chemical Products  1.806735e+12
# 5                         Foodstuffs  6.194238e+11
# 6              Footwear and Headwear  1.714520e+11
# 7                        Instruments  6.957446e+11
# 8                           Machines  4.703932e+12
# 9                             Metals  1.240102e+12
# 10                  Mineral Products  2.507501e+12
# 11                     Miscellaneous  4.149646e+11
# 12                       Paper Goods  2.740448e+11
# 13              Plastics and Rubbers  8.169171e+11
# 14                   Precious Metals  6.539647e+11
# 15                   Stone And Glass  1.847948e+11
# 16                          Textiles  8.017909e+11
# 17                    Transportation  1.937529e+12
# 18                Vegetable Products  5.119514e+11
# 19                           Weapons  1.580201e+10
# 20                     Wood Products  1.426583e+11

# %%
def barplot(data):
  fig = px.bar(data, x=dt.Section, y=dt['Trade Value'], color=dt.Section)
  fig.update_xaxes(title_text = "Steel Products", rangeslider_visible=False, showline=True, linewidth=2, linecolor='black', mirror=True)
  fig.update_yaxes(title_text = 'Trade Value', showline=True, linewidth=2, linecolor='black', mirror=True)
  # fig.update_traces(marker_color='rgb(158,202,225)', marker_line_color='rgb(8,48,107)', marker_line_width=1.5, opacity=0.6)
  fig.update_layout(height=600, width=1400, title_text='Trade Values for Steel Related Products') 
  fig.show()

barplot(dt)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="41ef5d05-21fd-4ba5-814e-d255fbdb25fb" class="plotly-graph-div" style="height:600px; width:1400px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("41ef5d05-21fd-4ba5-814e-d255fbdb25fb")) {                    Plotly.newPlot(                        "41ef5d05-21fd-4ba5-814e-d255fbdb25fb",                        [{"alignmentgroup":"True","hovertemplate":"Section=%{x}<br>Trade Value=%{y}<extra></extra>","legendgroup":"Animal Hides","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Animal Hides","offsetgroup":"Animal Hides","orientation":"v","showlegend":true,"textposition":"auto","x":["Animal Hides"],"xaxis":"x","y":[104182930770.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Section=%{x}<br>Trade Value=%{y}<extra></extra>","legendgroup":"Animal Products","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Animal Products","offsetgroup":"Animal Products","orientation":"v","showlegend":true,"textposition":"auto","x":["Animal Products"],"xaxis":"x","y":[378702323801.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Section=%{x}<br>Trade Value=%{y}<extra></extra>","legendgroup":"Animal and Vegetable Bi-Products","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Animal and Vegetable Bi-Products","offsetgroup":"Animal and Vegetable Bi-Products","orientation":"v","showlegend":true,"textposition":"auto","x":["Animal and Vegetable Bi-Products"],"xaxis":"x","y":[100444869417.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Section=%{x}<br>Trade Value=%{y}<extra></extra>","legendgroup":"Arts and Antiques","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Arts and Antiques","offsetgroup":"Arts and Antiques","orientation":"v","showlegend":true,"textposition":"auto","x":["Arts and Antiques"],"xaxis":"x","y":[26992566174.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Section=%{x}<br>Trade Value=%{y}<extra></extra>","legendgroup":"Chemical Products","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Chemical Products","offsetgroup":"Chemical Products","orientation":"v","showlegend":true,"textposition":"auto","x":["Chemical Products"],"xaxis":"x","y":[1806734599483.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Section=%{x}<br>Trade Value=%{y}<extra></extra>","legendgroup":"Foodstuffs","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Foodstuffs","offsetgroup":"Foodstuffs","orientation":"v","showlegend":true,"textposition":"auto","x":["Foodstuffs"],"xaxis":"x","y":[619423764060.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Section=%{x}<br>Trade Value=%{y}<extra></extra>","legendgroup":"Footwear and Headwear","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Footwear and Headwear","offsetgroup":"Footwear and Headwear","orientation":"v","showlegend":true,"textposition":"auto","x":["Footwear and Headwear"],"xaxis":"x","y":[171451980520.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Section=%{x}<br>Trade Value=%{y}<extra></extra>","legendgroup":"Instruments","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Instruments","offsetgroup":"Instruments","orientation":"v","showlegend":true,"textposition":"auto","x":["Instruments"],"xaxis":"x","y":[695744623381.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Section=%{x}<br>Trade Value=%{y}<extra></extra>","legendgroup":"Machines","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Machines","offsetgroup":"Machines","orientation":"v","showlegend":true,"textposition":"auto","x":["Machines"],"xaxis":"x","y":[4703931561326.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Section=%{x}<br>Tra ...

# %%
dt = dt[["Section", 'Trade Value']].groupby("Section").sum()
dt = dt.reset_index()
fig = go.Figure(data=[go.Pie(labels=dt["Section"], values=dt['Trade Value'], hole=.5)])
fig.update_layout(height=700, width=1400, title_text='Percentage Distribution of Trade Values for Steel Products') 
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="41cb40af-b5b4-410a-ae84-a3ab3b83fbe6" class="plotly-graph-div" style="height:700px; width:1400px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("41cb40af-b5b4-410a-ae84-a3ab3b83fbe6")) {                    Plotly.newPlot(                        "41cb40af-b5b4-410a-ae84-a3ab3b83fbe6",                        [{"hole":0.5,"labels":["Animal Hides","Animal Products","Animal and Vegetable Bi-Products","Arts and Antiques","Chemical Products","Foodstuffs","Footwear and Headwear","Instruments","Machines","Metals","Mineral Products","Miscellaneous","Paper Goods","Plastics and Rubbers","Precious Metals","Stone And Glass","Textiles","Transportation","Vegetable Products","Weapons","Wood Products"],"values":[104182930770.0,378702323801.0,100444869417.0,26992566174.0,1806734599483.0,619423764060.0,171451980520.0,695744623381.0,4703931561326.0,1240101783819.0,2507501222090.0,414964552142.0,274044838306.0,816917114274.0,653964673538.0,184794778522.0,801790872336.0,1937529478292.0,511951419313.0,15802013952.0,142658271429.0],"type":"pie"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.88 ...

# %% [markdown]
# ### **GROUP BY SECTION: Animal Products**

# %%
dt = data[["Section", 'HS2', 'Trade Value']]
dt = dt[dt["Section"] == 'Animal Products']
dt = dt.groupby(['HS2']).sum().reset_index()
dt
# Out:
#                                                  HS2   Trade Value
# 0  Animal originated products; not elsewhere spec...  1.146496e+10
# 1  Dairy products and other edible products of an...  8.981281e+10
# 2  Fish and crustaceans, molluscs and other aquat...  1.194437e+11
# 3                                       Live animals  2.270985e+10
# 4                         Meat and edible meat offal  1.352710e+11

# %%
def barplot(data):
  fig = px.bar(dt, x=dt.HS2, y=dt['Trade Value'], color=dt.HS2)
  fig.update_xaxes(title_text = "Animal Steel Products", rangeslider_visible=True, showline=True, linewidth=2, linecolor='black', mirror=True)
  fig.update_yaxes(title_text = 'Trade Value', showline=True, linewidth=2, linecolor='black', mirror=True)
  # fig.update_traces(marker_color='rgb(158,202,225)', marker_line_color='rgb(8,48,107)', marker_line_width=1.5, opacity=0.6)
  fig.update_layout(height=900, width=1400, title_text='Trade Values for Animal Steel Products') 
  fig.show()

barplot(dt)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="2c9abfa4-9edc-4362-acba-97836d059b82" class="plotly-graph-div" style="height:900px; width:1400px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2c9abfa4-9edc-4362-acba-97836d059b82")) {                    Plotly.newPlot(                        "2c9abfa4-9edc-4362-acba-97836d059b82",                        [{"alignmentgroup":"True","hovertemplate":"HS2=%{x}<br>Trade Value=%{y}<extra></extra>","legendgroup":"Animal originated products; not elsewhere specified or included","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Animal originated products; not elsewhere specified or included","offsetgroup":"Animal originated products; not elsewhere specified or included","orientation":"v","showlegend":true,"textposition":"auto","x":["Animal originated products; not elsewhere specified or included"],"xaxis":"x","y":[11464956673.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"HS2=%{x}<br>Trade Value=%{y}<extra></extra>","legendgroup":"Dairy products and other edible products of animal origin","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Dairy products and other edible products of animal origin","offsetgroup":"Dairy products and other edible products of animal origin","orientation":"v","showlegend":true,"textposition":"auto","x":["Dairy products and other edible products of animal origin"],"xaxis":"x","y":[89812813450.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"HS2=%{x}<br>Trade Value=%{y}<extra></extra>","legendgroup":"Fish and crustaceans, molluscs and other aquatic invertebrates","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Fish and crustaceans, molluscs and other aquatic invertebrates","offsetgroup":"Fish and crustaceans, molluscs and other aquatic invertebrates","orientation":"v","showlegend":true,"textposition":"auto","x":["Fish and crustaceans, molluscs and other aquatic invertebrates"],"xaxis":"x","y":[119443700139.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"HS2=%{x}<br>Trade Value=%{y}<extra></extra>","legendgroup":"Live animals","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Live animals","offsetgroup":"Live animals","orientation":"v","showlegend":true,"textposition":"auto","x":["Live animals"],"xaxis":"x","y":[22709851273.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"HS2=%{x}<br>Trade Value=%{y}<extra></extra>","legendgroup":"Meat and edible meat offal","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Meat and edible meat offal","offsetgroup":"Meat and edible meat offal","orientation":"v","showlegend":true,"textposition":"auto","x":["Meat and edible meat offal"],"xaxis":"x","y":[135271002266.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778," ...

# %%
dt = dt[["HS2", 'Trade Value']].groupby("HS2").sum()
dt = dt.reset_index()
fig = go.Figure(data=[go.Pie(labels=dt["HS2"], values=dt['Trade Value'], hole=.5)])
fig.update_layout(height=500, width=1400, title_text='Trade Percentage for Animal Steel Products') 
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="7e0f806f-5f5e-45f6-bd7d-ed063cbbc08e" class="plotly-graph-div" style="height:500px; width:1400px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7e0f806f-5f5e-45f6-bd7d-ed063cbbc08e")) {                    Plotly.newPlot(                        "7e0f806f-5f5e-45f6-bd7d-ed063cbbc08e",                        [{"hole":0.5,"labels":["Animal originated products; not elsewhere specified or included","Dairy products and other edible products of animal origin","Fish and crustaceans, molluscs and other aquatic invertebrates","Live animals","Meat and edible meat offal"],"values":[11464956673.0,89812813450.0,119443700139.0,22709851273.0,135271002266.0],"type":"pie"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line": ...

# %% [markdown]
# ### **GROUP BY SECTION: Vegetable Products**

# %%
dt = data[["Section", 'HS2', 'Trade Value']]
dt = dt[dt["Section"] == 'Vegetable Products']
dt = dt.groupby(['HS2']).sum().reset_index()
dt
# Out:
#                                                  HS2   Trade Value
# 0                                            Cereals  1.149180e+11
# 1                       Coffee, tea, mate and spices  4.881691e+10
# 2  Fruit and nuts, edible; peel of citrus fruit o...  1.292899e+11
# 3  Lac; gums, resins and other vegetable saps and...  8.070090e+09
# 4                    Oil seeds and oleaginous fruits  9.579020e+10
# 5  Products of the milling industry; malt, starch...  2.012838e+10
# 6                        Trees and other live plants  2.157703e+10
# 7                       Vegetable plaiting materials  1.200749e+09
# 8    Vegetables and certain roots and tubers; edible  7.216014e+10

# %%
def barplot(data):
  fig = px.bar(dt, x=dt.HS2, y=dt['Trade Value'], color=dt.HS2)
  fig.update_xaxes(title_text = "Vegatable Steel Products", rangeslider_visible=True, showline=True, linewidth=2, linecolor='black', mirror=True)
  fig.update_yaxes(title_text = 'Trade Value', showline=True, linewidth=2, linecolor='black', mirror=True)
  # fig.update_traces(marker_color='rgb(158,202,225)', marker_line_color='rgb(8,48,107)', marker_line_width=1.5, opacity=0.6)
  fig.update_layout(height=900, width=1400, title_text='Trade Values for Vegatable Steel Products') 
  fig.show()

barplot(dt)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="214c2a7f-fe73-4ad5-a0dd-9166ac3c73aa" class="plotly-graph-div" style="height:900px; width:1400px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("214c2a7f-fe73-4ad5-a0dd-9166ac3c73aa")) {                    Plotly.newPlot(                        "214c2a7f-fe73-4ad5-a0dd-9166ac3c73aa",                        [{"alignmentgroup":"True","hovertemplate":"HS2=%{x}<br>Trade Value=%{y}<extra></extra>","legendgroup":"Cereals","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Cereals","offsetgroup":"Cereals","orientation":"v","showlegend":true,"textposition":"auto","x":["Cereals"],"xaxis":"x","y":[114918000992.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"HS2=%{x}<br>Trade Value=%{y}<extra></extra>","legendgroup":"Coffee, tea, mate and spices","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Coffee, tea, mate and spices","offsetgroup":"Coffee, tea, mate and spices","orientation":"v","showlegend":true,"textposition":"auto","x":["Coffee, tea, mate and spices"],"xaxis":"x","y":[48816905980.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"HS2=%{x}<br>Trade Value=%{y}<extra></extra>","legendgroup":"Fruit and nuts, edible; peel of citrus fruit or melons","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Fruit and nuts, edible; peel of citrus fruit or melons","offsetgroup":"Fruit and nuts, edible; peel of citrus fruit or melons","orientation":"v","showlegend":true,"textposition":"auto","x":["Fruit and nuts, edible; peel of citrus fruit or melons"],"xaxis":"x","y":[129289917695.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"HS2=%{x}<br>Trade Value=%{y}<extra></extra>","legendgroup":"Lac; gums, resins and other vegetable saps and extracts","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Lac; gums, resins and other vegetable saps and extracts","offsetgroup":"Lac; gums, resins and other vegetable saps and extracts","orientation":"v","showlegend":true,"textposition":"auto","x":["Lac; gums, resins and other vegetable saps and extracts"],"xaxis":"x","y":[8070090123.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"HS2=%{x}<br>Trade Value=%{y}<extra></extra>","legendgroup":"Oil seeds and oleaginous fruits","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Oil seeds and oleaginous fruits","offsetgroup":"Oil seeds and oleaginous fruits","orientation":"v","showlegend":true,"textposition":"auto","x":["Oil seeds and oleaginous fruits"],"xaxis":"x","y":[95790201485.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"HS2=%{x}<br>Trade Value=%{y}<extra></extra>","legendgroup":"Products of the milling industry; malt, starches, inulin, wheat gluten","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Products of the milling industry; malt, starches, inulin, wheat gluten","offsetgroup":"Products of the milling industry; malt, starches, inulin, wheat gluten","orientation":"v","showlegend":true,"textposition":"auto","x":["Products of the milling industry; malt, starches, inulin, wheat gluten"],"xaxis":"x","y":[20128379787.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"HS2=%{x}<br>Trade Value=%{y}<extra></extra>","legendgroup":"Trees and other live plants","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Trees and other live plants","offsetgroup":"Trees and other live plants","orientation":"v","showlegend":true,"textposition":"auto","x":["Trees and other live plants"],"xaxis":"x","y":[21577034540.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"HS2=%{x}<br>Trade Value=%{y}<extra></extra>","legendgroup":"Vegetable plaiting materials","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Vegetable plai ...

# %%
dt = dt[["HS2", 'Trade Value']].groupby("HS2").sum()
dt = dt.reset_index()
fig = go.Figure(data=[go.Pie(labels=dt["HS2"], values=dt['Trade Value'], hole=.5)])
fig.update_layout(height=500, width=1400, title_text='Trade Percentage for Vegatable Steel Products') 
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="9cd8a9f0-c902-4750-9074-8cd5ca10682c" class="plotly-graph-div" style="height:500px; width:1400px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9cd8a9f0-c902-4750-9074-8cd5ca10682c")) {                    Plotly.newPlot(                        "9cd8a9f0-c902-4750-9074-8cd5ca10682c",                        [{"hole":0.5,"labels":["Cereals","Coffee, tea, mate and spices","Fruit and nuts, edible; peel of citrus fruit or melons","Lac; gums, resins and other vegetable saps and extracts","Oil seeds and oleaginous fruits","Products of the milling industry; malt, starches, inulin, wheat gluten","Trees and other live plants","Vegetable plaiting materials","Vegetables and certain roots and tubers; edible"],"values":[114918000992.0,48816905980.0,129289917695.0,8070090123.0,95790201485.0,20128379787.0,21577034540.0,1200749177.0,72160139534.0],"type":"pie"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"ou ...

# %% [markdown]
# ### **GROUP BY SECTION: Animal and Vegetable Bi-Products**

# %%
dt = data[["Section", 'HS2', 'Trade Value']]
dt = dt[dt["Section"] == 'Animal and Vegetable Bi-Products']
dt = dt.groupby(['HS2']).sum().reset_index()
dt
# Out:
#                                                  HS2   Trade Value
# 0  Animal or vegetable fats and oils and their cl...  1.004449e+11

# %%
def barplot(data):
  fig = px.bar(dt, x=dt.HS2, y=dt['Trade Value'], color=dt.HS2)
  fig.update_xaxes(title_text = "Animal and Vegatable Steel Products", rangeslider_visible=True, showline=True, linewidth=2, linecolor='black', mirror=True)
  fig.update_yaxes(title_text = 'Trade Value', showline=True, linewidth=2, linecolor='black', mirror=True)
  # fig.update_traces(marker_color='rgb(158,202,225)', marker_line_color='rgb(8,48,107)', marker_line_width=1.5, opacity=0.6)
  fig.update_layout(height=900, width=1400, title_text='Trade Values for Animal and Vegatable Steel Products') 
  fig.show()

barplot(dt)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="24f21808-87bc-407d-9b2c-72d0a0496d2e" class="plotly-graph-div" style="height:900px; width:1400px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("24f21808-87bc-407d-9b2c-72d0a0496d2e")) {                    Plotly.newPlot(                        "24f21808-87bc-407d-9b2c-72d0a0496d2e",                        [{"alignmentgroup":"True","hovertemplate":"HS2=%{x}<br>Trade Value=%{y}<extra></extra>","legendgroup":"Animal or vegetable fats and oils and their cleavage products","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Animal or vegetable fats and oils and their cleavage products","offsetgroup":"Animal or vegetable fats and oils and their cleavage products","orientation":"v","showlegend":true,"textposition":"auto","x":["Animal or vegetable fats and oils and their cleavage products"],"xaxis":"x","y":[100444869417.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar" ...

# %%
dt = dt[["HS2", 'Trade Value']].groupby("HS2").sum()
dt = dt.reset_index()
fig = go.Figure(data=[go.Pie(labels=dt["HS2"], values=dt['Trade Value'], hole=.5)])
fig.update_layout(height=500, width=1400, title_text='Trade Percentage for Animal and Vegatable Steel Products') 
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="99ea1419-11a5-4678-9dc6-ae3a9726ac38" class="plotly-graph-div" style="height:500px; width:1400px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("99ea1419-11a5-4678-9dc6-ae3a9726ac38")) {                    Plotly.newPlot(                        "99ea1419-11a5-4678-9dc6-ae3a9726ac38",                        [{"hole":0.5,"labels":["Animal or vegetable fats and oils and their cleavage products"],"values":[100444869417.0],"type":"pie"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattercarpet"}],"scattergeo":[{"m ...

# %% [markdown]
# ### **GROUP BY SECTION: Foodstuffs**

# %%
dt = data[["Section", 'HS2', 'Trade Value']]
dt = dt[dt["Section"] == 'Foodstuffs']
dt = dt.groupby(['HS2']).sum().reset_index()
dt
# Out:
#                                                  HS2   Trade Value
# 0                     Beverages, spirits and vinegar  1.235094e+11
# 1                       Cocoa and cocoa preparations  5.088032e+10
# 2  Food industries, residues and wastes thereof; ...  7.829006e+10
# 3  Meat, fish or crustaceans, molluscs or other a...  5.761321e+10
# 4                  Miscellaneous edible preparations  7.918772e+10
# 5  Preparations of cereals, flour, starch or milk...  7.838527e+10
# 6  Preparations of vegetables, fruit, nuts or oth...  6.437846e+10
# 7                     Sugars and sugar confectionery  4.094724e+10
# 8       Tobacco and manufactured tobacco substitutes  4.623208e+10

# %%
def barplot(data):
  fig = px.bar(dt, x=dt.HS2, y=dt['Trade Value'], color=dt.HS2)
  fig.update_xaxes(title_text = "Food Steel Products", rangeslider_visible=True, showline=True, linewidth=2, linecolor='black', mirror=True)
  fig.update_yaxes(title_text = 'Trade Value', showline=True, linewidth=2, linecolor='black', mirror=True)
  # fig.update_traces(marker_color='rgb(158,202,225)', marker_line_color='rgb(8,48,107)', marker_line_width=1.5, opacity=0.6)
  fig.update_layout(height=900, width=1400, title_text='Trade Values for Food Steel Products') 
  fig.show()

barplot(dt)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="8926574e-4466-4cb6-9019-66a87e403a73" class="plotly-graph-div" style="height:900px; width:1400px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8926574e-4466-4cb6-9019-66a87e403a73")) {                    Plotly.newPlot(                        "8926574e-4466-4cb6-9019-66a87e403a73",                        [{"alignmentgroup":"True","hovertemplate":"HS2=%{x}<br>Trade Value=%{y}<extra></extra>","legendgroup":"Beverages, spirits and vinegar","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Beverages, spirits and vinegar","offsetgroup":"Beverages, spirits and vinegar","orientation":"v","showlegend":true,"textposition":"auto","x":["Beverages, spirits and vinegar"],"xaxis":"x","y":[123509408559.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"HS2=%{x}<br>Trade Value=%{y}<extra></extra>","legendgroup":"Cocoa and cocoa preparations","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Cocoa and cocoa preparations","offsetgroup":"Cocoa and cocoa preparations","orientation":"v","showlegend":true,"textposition":"auto","x":["Cocoa and cocoa preparations"],"xaxis":"x","y":[50880315928.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"HS2=%{x}<br>Trade Value=%{y}<extra></extra>","legendgroup":"Food industries, residues and wastes thereof; prepared animal fodder","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Food industries, residues and wastes thereof; prepared animal fodder","offsetgroup":"Food industries, residues and wastes thereof; prepared animal fodder","orientation":"v","showlegend":true,"textposition":"auto","x":["Food industries, residues and wastes thereof; prepared animal fodder"],"xaxis":"x","y":[78290062476.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"HS2=%{x}<br>Trade Value=%{y}<extra></extra>","legendgroup":"Meat, fish or crustaceans, molluscs or other aquatic invertebrates","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Meat, fish or crustaceans, molluscs or other aquatic invertebrates","offsetgroup":"Meat, fish or crustaceans, molluscs or other aquatic invertebrates","orientation":"v","showlegend":true,"textposition":"auto","x":["Meat, fish or crustaceans, molluscs or other aquatic invertebrates"],"xaxis":"x","y":[57613214721.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"HS2=%{x}<br>Trade Value=%{y}<extra></extra>","legendgroup":"Miscellaneous edible preparations","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Miscellaneous edible preparations","offsetgroup":"Miscellaneous edible preparations","orientation":"v","showlegend":true,"textposition":"auto","x":["Miscellaneous edible preparations"],"xaxis":"x","y":[79187721832.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"HS2=%{x}<br>Trade Value=%{y}<extra></extra>","legendgroup":"Preparations of cereals, flour, starch or milk; pastrycooks' products","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Preparations of cereals, flour, starch or milk; pastrycooks' products","offsetgroup":"Preparations of cereals, flour, starch or milk; pastrycooks' products","orientation":"v","showlegend":true,"textposition":"auto","x":["Preparations of cereals, flour, starch or milk; pastrycooks' products"],"xaxis":"x","y":[78385272125.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"HS2=%{x}<br>Trade Value=%{y}<extra></extra>","legendgroup":"Preparations of vegetables, fruit, nuts or other parts of plants","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Preparations of vegetables, fruit, nuts or other parts of plants","offsetgroup":"Preparations of vegetables, fruit, nuts or other parts of plants","orientation":"v","showlegend":true,"textposition": ...

# %%
dt = dt[["HS2", 'Trade Value']].groupby("HS2").sum()
dt = dt.reset_index()
fig = go.Figure(data=[go.Pie(labels=dt["HS2"], values=dt['Trade Value'], hole=.5)])
fig.update_layout(height=500, width=1400, title_text='Trade Percentage for Food Steel Products') 
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="7b8aeec8-3da2-4e0b-a379-8c48310bbc44" class="plotly-graph-div" style="height:500px; width:1400px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7b8aeec8-3da2-4e0b-a379-8c48310bbc44")) {                    Plotly.newPlot(                        "7b8aeec8-3da2-4e0b-a379-8c48310bbc44",                        [{"hole":0.5,"labels":["Beverages, spirits and vinegar","Cocoa and cocoa preparations","Food industries, residues and wastes thereof; prepared animal fodder","Meat, fish or crustaceans, molluscs or other aquatic invertebrates","Miscellaneous edible preparations","Preparations of cereals, flour, starch or milk; pastrycooks' products","Preparations of vegetables, fruit, nuts or other parts of plants","Sugars and sugar confectionery","Tobacco and manufactured tobacco substitutes"],"values":[123509408559.0,50880315928.0,78290062476.0,57613214721.0,79187721832.0,78385272125.0,64378457614.0,40947235247.0,46232075558.0],"type":"pie"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar" ...

# %% [markdown]
# ### **GROUP BY SECTION: Mineral Products**

# %%
dt = data[["Section", 'HS2', 'Trade Value']]
dt = dt[dt["Section"] == 'Mineral Products']
dt = dt.groupby(['HS2']).sum().reset_index()
dt
# Out:
#                                                  HS2   Trade Value
# 0  Mineral fuels, mineral oils and products of th...  2.206368e+12
# 1                                 Ores, slag and ash  2.512176e+11
# 2  Salt; sulphur; earths, stone; plastering mater...  4.991561e+10

# %%
def barplot(data):
  fig = px.bar(dt, x=dt.HS2, y=dt['Trade Value'], color=dt.HS2)
  fig.update_xaxes(title_text = "Mineral Steel Products", rangeslider_visible=True, showline=True, linewidth=2, linecolor='black', mirror=True)
  fig.update_yaxes(title_text = 'Trade Value', showline=True, linewidth=2, linecolor='black', mirror=True)
  # fig.update_traces(marker_color='rgb(158,202,225)', marker_line_color='rgb(8,48,107)', marker_line_width=1.5, opacity=0.6)
  fig.update_layout(height=900, width=1400, title_text='Trade Values for Mineral Steel Products') 
  fig.show()

barplot(dt)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="d9e7e1ef-a41e-4eb3-ba0f-fc6c8cc5c90c" class="plotly-graph-div" style="height:900px; width:1400px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d9e7e1ef-a41e-4eb3-ba0f-fc6c8cc5c90c")) {                    Plotly.newPlot(                        "d9e7e1ef-a41e-4eb3-ba0f-fc6c8cc5c90c",                        [{"alignmentgroup":"True","hovertemplate":"HS2=%{x}<br>Trade Value=%{y}<extra></extra>","legendgroup":"Mineral fuels, mineral oils and products of their distillation","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Mineral fuels, mineral oils and products of their distillation","offsetgroup":"Mineral fuels, mineral oils and products of their distillation","orientation":"v","showlegend":true,"textposition":"auto","x":["Mineral fuels, mineral oils and products of their distillation"],"xaxis":"x","y":[2206368025255.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"HS2=%{x}<br>Trade Value=%{y}<extra></extra>","legendgroup":"Ores, slag and ash","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Ores, slag and ash","offsetgroup":"Ores, slag and ash","orientation":"v","showlegend":true,"textposition":"auto","x":["Ores, slag and ash"],"xaxis":"x","y":[251217583700.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"HS2=%{x}<br>Trade Value=%{y}<extra></extra>","legendgroup":"Salt; sulphur; earths, stone; plastering materials, lime and cement","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Salt; sulphur; earths, stone; plastering materials, lime and cement","offsetgroup":"Salt; sulphur; earths, stone; plastering materials, lime and cement","orientation":"v","showlegend":true,"textposition":"auto","x":["Salt; sulphur; earths, stone; plastering materials, lime and cement"],"xaxis":"x","y":[49915613135.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogr ...

# %%
dt = dt[["HS2", 'Trade Value']].groupby("HS2").sum()
dt = dt.reset_index()
fig = go.Figure(data=[go.Pie(labels=dt["HS2"], values=dt['Trade Value'], hole=.5)])
fig.update_layout(height=500, width=1400, title_text='Trade Percentage for Mineral Steel Products') 
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="af85acc0-a383-49bb-841d-b4ab2d963e7b" class="plotly-graph-div" style="height:500px; width:1400px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("af85acc0-a383-49bb-841d-b4ab2d963e7b")) {                    Plotly.newPlot(                        "af85acc0-a383-49bb-841d-b4ab2d963e7b",                        [{"hole":0.5,"labels":["Mineral fuels, mineral oils and products of their distillation","Ores, slag and ash","Salt; sulphur; earths, stone; plastering materials, lime and cement"],"values":[2206368025255.0,251217583700.0,49915613135.0],"type":"pie"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"sca ...

# %% [markdown]
# ### **GROUP BY SECTION: Chemical Products**

# %%
dt = data[["Section", 'HS2', 'Trade Value']]
dt = dt[dt["Section"] == 'Chemical Products']
dt = dt.groupby(['HS2']).sum().reset_index()
dt
# Out:
#                                                   HS2   Trade Value
# 0   Albuminoidal substances; modified starches; gl...  3.026782e+10
# 1                            Chemical products n.e.s.  2.012178e+11
# 2   Essential oils and resinoids; perfumery, cosme...  1.416587e+11
# 3   Explosives; pyrotechnic products; matches; pyr...  4.926792e+09
# 4                                         Fertilizers  6.655703e+10
# 5   Inorganic chemicals; organic and inorganic com...  1.291241e+11
# 6                                   Organic chemicals  4.357012e+11
# 7                             Pharmaceutical products  6.363735e+11
# 8               Photographic or cinematographic goods  1.546032e+10
# 9   Soap, organic surface-active agents; washing, ...  6.258880e+10
# 10  Tanning or dyeing extracts; tannins and their ...  8.285854e+10

# %%
def barplot(data):
  fig = px.bar(dt, x=dt.HS2, y=dt['Trade Value'])
  fig.update_xaxes(title_text = "Chemical Steel Products", rangeslider_visible=False, showline=True, linewidth=2, linecolor='black', mirror=True)
  fig.update_yaxes(title_text = 'Trade Value', showline=True, linewidth=2, linecolor='black', mirror=True)
  # fig.update_traces(marker_color='rgb(158,202,225)', marker_line_color='rgb(8,48,107)', marker_line_width=1.5, opacity=0.6)
  fig.update_layout(height=2000, width=1400, title_text='Trade Values for Chemical Steel Products') 
  fig.show()

barplot(dt)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="5c5eb6e4-c96a-4e32-8186-621e647ec6fa" class="plotly-graph-div" style="height:2000px; width:1400px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5c5eb6e4-c96a-4e32-8186-621e647ec6fa")) {                    Plotly.newPlot(                        "5c5eb6e4-c96a-4e32-8186-621e647ec6fa",                        [{"alignmentgroup":"True","hovertemplate":"HS2=%{x}<br>Trade Value=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Albuminoidal substances; modified starches; glues; enzymes","Chemical products n.e.s.","Essential oils and resinoids; perfumery, cosmetic or toilet preparations","Explosives; pyrotechnic products; matches; pyrophoric alloys; certain combustible preparations","Fertilizers","Inorganic chemicals; organic and inorganic compounds of precious metals; of rare earth metals, of radio-active elements and of isotopes","Organic chemicals","Pharmaceutical products","Photographic or cinematographic goods","Soap, organic surface-active agents; washing, lubricating, polishing or scouring preparations; artificial or prepared waxes, candles and similar articles, modelling pastes, dental waxes\" and dental preparations with a basis of plaster\"","Tanning or dyeing extracts; tannins and their derivatives; dyes, pigments and other colouring matter; paints, varnishes; putty, other mastics; inks"],"xaxis":"x","y":[30267818683.0,201217795043.0,141658735507.0,4926792434.0,66557033750.0,129124096911.0,435701190776.0,636373477481.0,15460315150.0,62588802783.0,82858540965.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d ...

# %%
dt = dt[["HS2", 'Trade Value']].groupby("HS2").sum()
dt = dt.reset_index()
fig = go.Figure(data=[go.Pie(labels=dt["HS2"], values=dt['Trade Value'], hole=.5)])
fig.update_layout(height=500, width=1400, title_text='Trade Percentage for Chemical Steel Products') 
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="527791c7-c765-435e-aab9-75c40c4797ba" class="plotly-graph-div" style="height:500px; width:1400px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("527791c7-c765-435e-aab9-75c40c4797ba")) {                    Plotly.newPlot(                        "527791c7-c765-435e-aab9-75c40c4797ba",                        [{"hole":0.5,"labels":["Albuminoidal substances; modified starches; glues; enzymes","Chemical products n.e.s.","Essential oils and resinoids; perfumery, cosmetic or toilet preparations","Explosives; pyrotechnic products; matches; pyrophoric alloys; certain combustible preparations","Fertilizers","Inorganic chemicals; organic and inorganic compounds of precious metals; of rare earth metals, of radio-active elements and of isotopes","Organic chemicals","Pharmaceutical products","Photographic or cinematographic goods","Soap, organic surface-active agents; washing, lubricating, polishing or scouring preparations; artificial or prepared waxes, candles and similar articles, modelling pastes, dental waxes\" and dental preparations with a basis of plaster\"","Tanning or dyeing extracts; tannins and their derivatives; dyes, pigments and other colouring matter; paints, varnishes; putty, other mastics; inks"],"values":[30267818683.0,201217795043.0,141658735507.0,4926792434.0,66557033750.0,129124096911.0,435701190776.0,636373477481.0,15460315150.0,62588802783.0,82858540965.0],"type":"pie"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888," ...

# %% [markdown]
# ### **GROUP BY SECTION: Plastics and Rubbers**

# %%
dt = data[["Section", 'HS2', 'Trade Value']]
dt = dt[dt["Section"] == 'Plastics and Rubbers']
dt = dt.groupby(['HS2']).sum().reset_index()
dt
# Out:
#                              HS2   Trade Value
# 0  Plastics and articles thereof  6.277963e+11
# 1    Rubber and articles thereof  1.891208e+11

# %%
def barplot(data):
  fig = px.bar(dt, x=dt.HS2, y=dt['Trade Value'], color=dt.HS2)
  fig.update_xaxes(title_text = "Plastics and Rubbers Products", rangeslider_visible=True, showline=True, linewidth=2, linecolor='black', mirror=True)
  fig.update_yaxes(title_text = 'Trade Value', showline=True, linewidth=2, linecolor='black', mirror=True)
  # fig.update_traces(marker_color='rgb(158,202,225)', marker_line_color='rgb(8,48,107)', marker_line_width=1.5, opacity=0.6)
  fig.update_layout(height=700, width=1400, title_text='Trade Values for Plastics and Rubbers Products') 
  fig.show()

barplot(dt)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="bab7347c-4123-4887-9d8a-f15d8d67c618" class="plotly-graph-div" style="height:700px; width:1400px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bab7347c-4123-4887-9d8a-f15d8d67c618")) {                    Plotly.newPlot(                        "bab7347c-4123-4887-9d8a-f15d8d67c618",                        [{"alignmentgroup":"True","hovertemplate":"HS2=%{x}<br>Trade Value=%{y}<extra></extra>","legendgroup":"Plastics and articles thereof","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Plastics and articles thereof","offsetgroup":"Plastics and articles thereof","orientation":"v","showlegend":true,"textposition":"auto","x":["Plastics and articles thereof"],"xaxis":"x","y":[627796304384.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"HS2=%{x}<br>Trade Value=%{y}<extra></extra>","legendgroup":"Rubber and articles thereof","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Rubber and articles thereof","offsetgroup":"Rubber and articles thereof","orientation":"v","showlegend":true,"textposition":"auto","x":["Rubber and articles thereof"],"xaxis":"x","y":[189120809890.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.444444444444 ...

# %%
dt = dt[["HS2", 'Trade Value']].groupby("HS2").sum()
dt = dt.reset_index()
fig = go.Figure(data=[go.Pie(labels=dt["HS2"], values=dt['Trade Value'], hole=.5)])
fig.update_layout(height=500, width=1400, title_text='Trade Percentage for Plastic and Rubber Products') 
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="a7fad8f9-fd4f-4d6a-9d11-8fd8200327be" class="plotly-graph-div" style="height:500px; width:1400px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a7fad8f9-fd4f-4d6a-9d11-8fd8200327be")) {                    Plotly.newPlot(                        "a7fad8f9-fd4f-4d6a-9d11-8fd8200327be",                        [{"hole":0.5,"labels":["Plastics and articles thereof","Rubber and articles thereof"],"values":[627796304384.0,189120809890.0],"type":"pie"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattercarpet"}],"sca ...

# %% [markdown]
# ### **GROUP BY SECTION: Animal Hides**

# %%
dt = data[["Section", 'HS2', 'Trade Value']]
dt = dt[dt["Section"] == 'Animal Hides']
dt = dt.groupby(['HS2']).sum().reset_index()
dt
# Out:
#                                                  HS2   Trade Value
# 0  Articles of leather; saddlery and harness; tra...  7.906297e+10
# 1  Furskins and artificial fur; manufactures thereof  5.264981e+09
# 2  Raw hides and skins (other than furskins) and ...  1.985498e+10

# %%
def barplot(data):
  fig = px.bar(dt, x=dt.HS2, y=dt['Trade Value'], color=dt.HS2)
  fig.update_xaxes(title_text = "Animal Hide Products", rangeslider_visible=False, showline=True, linewidth=2, linecolor='black', mirror=True)
  fig.update_yaxes(title_text = 'Trade Value', showline=True, linewidth=2, linecolor='black', mirror=True)
  # fig.update_traces(marker_color='rgb(158,202,225)', marker_line_color='rgb(8,48,107)', marker_line_width=1.5, opacity=0.6)
  fig.update_layout(height=1000, width=1400, title_text='Trade Values for Animal Hide Products') 
  fig.show()

barplot(dt)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="a63cf213-0862-4982-8cdd-1ef49074ea7c" class="plotly-graph-div" style="height:1000px; width:1400px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a63cf213-0862-4982-8cdd-1ef49074ea7c")) {                    Plotly.newPlot(                        "a63cf213-0862-4982-8cdd-1ef49074ea7c",                        [{"alignmentgroup":"True","hovertemplate":"HS2=%{x}<br>Trade Value=%{y}<extra></extra>","legendgroup":"Articles of leather; saddlery and harness; travel goods, handbags and similar containers; articles of animal gut (other than silk-worm gut)","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Articles of leather; saddlery and harness; travel goods, handbags and similar containers; articles of animal gut (other than silk-worm gut)","offsetgroup":"Articles of leather; saddlery and harness; travel goods, handbags and similar containers; articles of animal gut (other than silk-worm gut)","orientation":"v","showlegend":true,"textposition":"auto","x":["Articles of leather; saddlery and harness; travel goods, handbags and similar containers; articles of animal gut (other than silk-worm gut)"],"xaxis":"x","y":[79062974329.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"HS2=%{x}<br>Trade Value=%{y}<extra></extra>","legendgroup":"Furskins and artificial fur; manufactures thereof","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Furskins and artificial fur; manufactures thereof","offsetgroup":"Furskins and artificial fur; manufactures thereof","orientation":"v","showlegend":true,"textposition":"auto","x":["Furskins and artificial fur; manufactures thereof"],"xaxis":"x","y":[5264981220.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"HS2=%{x}<br>Trade Value=%{y}<extra></extra>","legendgroup":"Raw hides and skins (other than furskins) and leather","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Raw hides and skins (other than furskins) and leather","offsetgroup":"Raw hides and skins (other than furskins) and leather","orientation":"v","showlegend":true,"textposition":"auto","x":["Raw hides and skins (other than furskins) and leather"],"xaxis":"x","y":[19854975221.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatm ...

# %%
dt = dt[["HS2", 'Trade Value']].groupby("HS2").sum()
dt = dt.reset_index()
fig = go.Figure(data=[go.Pie(labels=dt["HS2"], values=dt['Trade Value'], hole=.5)])
fig.update_layout(height=500, width=1400, title_text='Trade Percentage for Animal Hide Products') 
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="5a0b14d9-69e1-4371-ba0b-12d287d2635f" class="plotly-graph-div" style="height:500px; width:1400px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5a0b14d9-69e1-4371-ba0b-12d287d2635f")) {                    Plotly.newPlot(                        "5a0b14d9-69e1-4371-ba0b-12d287d2635f",                        [{"hole":0.5,"labels":["Articles of leather; saddlery and harness; travel goods, handbags and similar containers; articles of animal gut (other than silk-worm gut)","Furskins and artificial fur; manufactures thereof","Raw hides and skins (other than furskins) and leather"],"values":[79062974329.0,5264981220.0,19854975221.0],"type":"pie"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"ou ...

# %% [markdown]
# ### **GROUP BY SECTION: Wood Products**

# %%
dt = data[["Section", 'HS2', 'Trade Value']]
dt = dt[dt["Section"] == 'Wood Products']
dt = dt.groupby(['HS2']).sum().reset_index()
dt
# Out:
#                                                  HS2   Trade Value
# 0                          Cork and articles of cork  1.982567e+09
# 1  Manufactures of straw, esparto or other plaiti...  2.475423e+09
# 2           Wood and articles of wood; wood charcoal  1.382003e+11

# %%
def barplot(data):
  fig = px.bar(dt, x=dt.HS2, y=dt['Trade Value'], color=dt.HS2)
  fig.update_xaxes(title_text = "Wood Products", rangeslider_visible=False, showline=True, linewidth=2, linecolor='black', mirror=True)
  fig.update_yaxes(title_text = 'Trade Value', showline=True, linewidth=2, linecolor='black', mirror=True)
  # fig.update_traces(marker_color='rgb(158,202,225)', marker_line_color='rgb(8,48,107)', marker_line_width=1.5, opacity=0.6)
  fig.update_layout(height=700, width=1400, title_text='Trade Values for Wood Products') 
  fig.show()

barplot(dt)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="4cf3aaa2-fb1e-41dc-bc4d-57f1a34437b9" class="plotly-graph-div" style="height:700px; width:1400px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4cf3aaa2-fb1e-41dc-bc4d-57f1a34437b9")) {                    Plotly.newPlot(                        "4cf3aaa2-fb1e-41dc-bc4d-57f1a34437b9",                        [{"alignmentgroup":"True","hovertemplate":"HS2=%{x}<br>Trade Value=%{y}<extra></extra>","legendgroup":"Cork and articles of cork","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Cork and articles of cork","offsetgroup":"Cork and articles of cork","orientation":"v","showlegend":true,"textposition":"auto","x":["Cork and articles of cork"],"xaxis":"x","y":[1982567335.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"HS2=%{x}<br>Trade Value=%{y}<extra></extra>","legendgroup":"Manufactures of straw, esparto or other plaiting materials; basketware and wickerwork","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Manufactures of straw, esparto or other plaiting materials; basketware and wickerwork","offsetgroup":"Manufactures of straw, esparto or other plaiting materials; basketware and wickerwork","orientation":"v","showlegend":true,"textposition":"auto","x":["Manufactures of straw, esparto or other plaiting materials; basketware and wickerwork"],"xaxis":"x","y":[2475423070.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"HS2=%{x}<br>Trade Value=%{y}<extra></extra>","legendgroup":"Wood and articles of wood; wood charcoal","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Wood and articles of wood; wood charcoal","offsetgroup":"Wood and articles of wood; wood charcoal","orientation":"v","showlegend":true,"textposition":"auto","x":["Wood and articles of wood; wood charcoal"],"xaxis":"x","y":[138200281024.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}], ...

# %%
dt = dt[["HS2", 'Trade Value']].groupby("HS2").sum()
dt = dt.reset_index()
fig = go.Figure(data=[go.Pie(labels=dt["HS2"], values=dt['Trade Value'], hole=.5)])
fig.update_layout(height=500, width=1400, title_text='Trade Percentage for Wood Steel Products') 
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="697048a4-ed02-419c-8e45-5acebb8efa7d" class="plotly-graph-div" style="height:500px; width:1400px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("697048a4-ed02-419c-8e45-5acebb8efa7d")) {                    Plotly.newPlot(                        "697048a4-ed02-419c-8e45-5acebb8efa7d",                        [{"hole":0.5,"labels":["Cork and articles of cork","Manufactures of straw, esparto or other plaiting materials; basketware and wickerwork","Wood and articles of wood; wood charcoal"],"values":[1982567335.0,2475423070.0,138200281024.0],"type":"pie"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scat ...

# %% [markdown]
# ### **GROUP BY SECTION: Paper Goods**

# %%
dt = data[["Section", 'HS2', 'Trade Value']]
dt = dt[dt["Section"] == 'Paper Goods']
dt = dt.groupby(['HS2']).sum().reset_index()
dt
# Out:
#                                                  HS2   Trade Value
# 0  Paper and paperboard; articles of paper pulp, ...  1.864539e+11
# 1  Printed books, newspapers, pictures and other ...  3.705342e+10
# 2  Pulp of wood or other fibrous cellulosic mater...  5.053751e+10

# %%
def barplot(data):
  fig = px.bar(dt, x=dt.HS2, y=dt['Trade Value'], color=dt.HS2)
  fig.update_xaxes(title_text = "Paper Products", rangeslider_visible=False, showline=True, linewidth=2, linecolor='black', mirror=True)
  fig.update_yaxes(title_text = 'Trade Value', showline=True, linewidth=2, linecolor='black', mirror=True)
  # fig.update_traces(marker_color='rgb(158,202,225)', marker_line_color='rgb(8,48,107)', marker_line_width=1.5, opacity=0.6)
  fig.update_layout(height=900, width=1400, title_text='Trade Values for Paper Products') 
  fig.show()

barplot(dt)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="92cb4bc2-7f58-4488-8866-08310135c504" class="plotly-graph-div" style="height:900px; width:1400px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("92cb4bc2-7f58-4488-8866-08310135c504")) {                    Plotly.newPlot(                        "92cb4bc2-7f58-4488-8866-08310135c504",                        [{"alignmentgroup":"True","hovertemplate":"HS2=%{x}<br>Trade Value=%{y}<extra></extra>","legendgroup":"Paper and paperboard; articles of paper pulp, of paper or paperboard","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Paper and paperboard; articles of paper pulp, of paper or paperboard","offsetgroup":"Paper and paperboard; articles of paper pulp, of paper or paperboard","orientation":"v","showlegend":true,"textposition":"auto","x":["Paper and paperboard; articles of paper pulp, of paper or paperboard"],"xaxis":"x","y":[186453910603.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"HS2=%{x}<br>Trade Value=%{y}<extra></extra>","legendgroup":"Printed books, newspapers, pictures and other products of the printing industry; manuscripts, typescripts and plans","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Printed books, newspapers, pictures and other products of the printing industry; manuscripts, typescripts and plans","offsetgroup":"Printed books, newspapers, pictures and other products of the printing industry; manuscripts, typescripts and plans","orientation":"v","showlegend":true,"textposition":"auto","x":["Printed books, newspapers, pictures and other products of the printing industry; manuscripts, typescripts and plans"],"xaxis":"x","y":[37053415334.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"HS2=%{x}<br>Trade Value=%{y}<extra></extra>","legendgroup":"Pulp of wood or other fibrous cellulosic material; waste and scrap of paper or paperboard","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Pulp of wood or other fibrous cellulosic material; waste and scrap of paper or paperboard","offsetgroup":"Pulp of wood or other fibrous cellulosic material; waste and scrap of paper or paperboard","orientation":"v","showlegend":true,"textposition":"auto","x":["Pulp of wood or other fibrous cellulosic material; waste and scrap of paper or paperboard"],"xaxis":"x","y":[50537512369.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666 ...

# %%
dt = dt[["HS2", 'Trade Value']].groupby("HS2").sum()
dt = dt.reset_index()
fig = go.Figure(data=[go.Pie(labels=dt["HS2"], values=dt['Trade Value'], hole=.5)])
fig.update_layout(height=500, width=1400, title_text='Trade Percentage for Paper Steel Products') 
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="5b33c9fa-3b4f-4c03-b7f8-934acae60367" class="plotly-graph-div" style="height:500px; width:1400px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5b33c9fa-3b4f-4c03-b7f8-934acae60367")) {                    Plotly.newPlot(                        "5b33c9fa-3b4f-4c03-b7f8-934acae60367",                        [{"hole":0.5,"labels":["Paper and paperboard; articles of paper pulp, of paper or paperboard","Printed books, newspapers, pictures and other products of the printing industry; manuscripts, typescripts and plans","Pulp of wood or other fibrous cellulosic material; waste and scrap of paper or paperboard"],"values":[186453910603.0,37053415334.0,50537512369.0],"type":"pie"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"sca ...

# %% [markdown]
# ### **GROUP BY SECTION: Textiles**

# %%
dt = data[["Section", 'HS2', 'Trade Value']]
dt = dt[dt["Section"] == 'Textiles']
dt = dt.groupby(['HS2']).sum().reset_index()
dt
# Out:
#                                                   HS2   Trade Value
# 0           Carpets and other textile floor coverings  1.562682e+10
# 1                                              Cotton  5.362972e+10
# 2                       Knitted or chrocheted fabrics  3.398023e+10
# 3   Knitted or crocheted apparel and clothing acce...  2.336496e+11
# 4                                  Man-made filaments  4.925089e+10
# 5                              Man-made staple fibres  3.791225e+10
# 6   Non-knit or crocheted apparel and clothing acc...  2.298128e+11
# 7                                                Silk  1.929846e+09
# 8                                     Textile fabrics  2.475534e+10
# 9   Textiles, made up articles; sets; worn clothin...  6.506942e+10
# 10  Vegetable textile fibres; paper yarn and woven...  4.809217e+09
# 11  Wadding, felt and nonwovens, special yarns; tw...  2.656474e+10
# 12  Wool, fine or coarse animal hair; horsehair ya...  1.281346e+10
# 13                                      Woven fabrics  1.198655e+10

# %%
def barplot(data):
  fig = px.bar(dt, x=dt.HS2, y=dt['Trade Value'], color=dt.HS2)
  fig.update_xaxes(title_text = "Textile Products", rangeslider_visible=True, showline=True, linewidth=2, linecolor='black', mirror=True)
  fig.update_yaxes(title_text = 'Trade Value', showline=True, linewidth=2, linecolor='black', mirror=True)
  # fig.update_traces(marker_color='rgb(158,202,225)', marker_line_color='rgb(8,48,107)', marker_line_width=1.5, opacity=0.6)
  fig.update_layout(height=900, width=1400, title_text='Trade Values for Textile Products') 
  fig.show()

barplot(dt)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="64268716-30ee-4282-9be0-1b7003eff5b9" class="plotly-graph-div" style="height:900px; width:1400px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("64268716-30ee-4282-9be0-1b7003eff5b9")) {                    Plotly.newPlot(                        "64268716-30ee-4282-9be0-1b7003eff5b9",                        [{"alignmentgroup":"True","hovertemplate":"HS2=%{x}<br>Trade Value=%{y}<extra></extra>","legendgroup":"Carpets and other textile floor coverings","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Carpets and other textile floor coverings","offsetgroup":"Carpets and other textile floor coverings","orientation":"v","showlegend":true,"textposition":"auto","x":["Carpets and other textile floor coverings"],"xaxis":"x","y":[15626817929.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"HS2=%{x}<br>Trade Value=%{y}<extra></extra>","legendgroup":"Cotton","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Cotton","offsetgroup":"Cotton","orientation":"v","showlegend":true,"textposition":"auto","x":["Cotton"],"xaxis":"x","y":[53629718621.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"HS2=%{x}<br>Trade Value=%{y}<extra></extra>","legendgroup":"Knitted or chrocheted fabrics","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Knitted or chrocheted fabrics","offsetgroup":"Knitted or chrocheted fabrics","orientation":"v","showlegend":true,"textposition":"auto","x":["Knitted or chrocheted fabrics"],"xaxis":"x","y":[33980228411.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"HS2=%{x}<br>Trade Value=%{y}<extra></extra>","legendgroup":"Knitted or crocheted apparel and clothing accessories","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Knitted or crocheted apparel and clothing accessories","offsetgroup":"Knitted or crocheted apparel and clothing accessories","orientation":"v","showlegend":true,"textposition":"auto","x":["Knitted or crocheted apparel and clothing accessories"],"xaxis":"x","y":[233649558043.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"HS2=%{x}<br>Trade Value=%{y}<extra></extra>","legendgroup":"Man-made filaments","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Man-made filaments","offsetgroup":"Man-made filaments","orientation":"v","showlegend":true,"textposition":"auto","x":["Man-made filaments"],"xaxis":"x","y":[49250889278.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"HS2=%{x}<br>Trade Value=%{y}<extra></extra>","legendgroup":"Man-made staple fibres","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Man-made staple fibres","offsetgroup":"Man-made staple fibres","orientation":"v","showlegend":true,"textposition":"auto","x":["Man-made staple fibres"],"xaxis":"x","y":[37912250053.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"HS2=%{x}<br>Trade Value=%{y}<extra></extra>","legendgroup":"Non-knit or crocheted apparel and clothing accessories","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Non-knit or crocheted apparel and clothing accessories","offsetgroup":"Non-knit or crocheted apparel and clothing accessories","orientation":"v","showlegend":true,"textposition":"auto","x":["Non-knit or crocheted apparel and clothing accessories"],"xaxis":"x","y":[229812840161.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"HS2=%{x}<br>Trade Value=%{y}<extra></extra>","legendgroup":"Silk","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Silk","offsetgroup":"Silk","orientation":"v","showlegend":true,"textposition":"auto","x":["Silk"],"xaxis":"x","y":[1929845931.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"HS2=%{x}<br>Trade Value=%{y}<extra>< ...

# %%
dt = dt[["HS2", 'Trade Value']].groupby("HS2").sum()
dt = dt.reset_index()
fig = go.Figure(data=[go.Pie(labels=dt["HS2"], values=dt['Trade Value'], hole=.5)])
fig.update_layout(height=500, width=1400, title_text='Trade Percentage for Textile Products')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="c66ea79a-1d78-4141-8add-65a3dc0e982b" class="plotly-graph-div" style="height:500px; width:1400px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c66ea79a-1d78-4141-8add-65a3dc0e982b")) {                    Plotly.newPlot(                        "c66ea79a-1d78-4141-8add-65a3dc0e982b",                        [{"hole":0.5,"labels":["Carpets and other textile floor coverings","Cotton","Knitted or chrocheted fabrics","Knitted or crocheted apparel and clothing accessories","Man-made filaments","Man-made staple fibres","Non-knit or crocheted apparel and clothing accessories","Silk","Textile fabrics","Textiles, made up articles; sets; worn clothing and worn textile articles; rags","Vegetable textile fibres; paper yarn and woven fabrics of paper yarn","Wadding, felt and nonwovens, special yarns; twine, cordage, ropes and cables and articles thereof","Wool, fine or coarse animal hair; horsehair yarn and woven fabric","Woven fabrics"],"values":[15626817929.0,53629718621.0,33980228411.0,233649558043.0,49250889278.0,37912250053.0,229812840161.0,1929845931.0,24755340230.0,65069419527.0,4809217121.0,26564739024.0,12813460247.0,11986547760.0],"type":"pie"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444 ...

# %% [markdown]
# ### **GROUP BY SECTION: Footwear and Headwear**

# %%
dt = data[["Section", 'HS2', 'Trade Value']]
dt = dt[dt["Section"] == 'Footwear and Headwear']
dt = dt.groupby(['HS2']).sum().reset_index()
dt
# Out:
#                                                  HS2   Trade Value
# 0  Feathers and down, prepared; and articles made...  8.180622e+09
# 1  Footwear; gaiters and the like; parts of such ...  1.490558e+11
# 2                         Headgear and parts thereof  1.062349e+10
# 3  Umbrellas, sun umbrellas, walking-sticks, seat...  3.592044e+09

# %%
def barplot(data):
  fig = px.bar(dt, x=dt.HS2, y=dt['Trade Value'], color=dt.HS2)
  fig.update_xaxes(title_text = "Footwear and Headwear Products", rangeslider_visible=False, showline=True, linewidth=2, linecolor='black', mirror=True)
  fig.update_yaxes(title_text = 'Trade Value', showline=True, linewidth=2, linecolor='black', mirror=True)
  # fig.update_traces(marker_color='rgb(158,202,225)', marker_line_color='rgb(8,48,107)', marker_line_width=1.5, opacity=0.6)
  fig.update_layout(height=900, width=1400, title_text='Trade Values for Footwear and Headwear Products') 
  fig.show()

barplot(dt)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="d579c8e1-31f6-497a-abcf-02d9007b6535" class="plotly-graph-div" style="height:900px; width:1400px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d579c8e1-31f6-497a-abcf-02d9007b6535")) {                    Plotly.newPlot(                        "d579c8e1-31f6-497a-abcf-02d9007b6535",                        [{"alignmentgroup":"True","hovertemplate":"HS2=%{x}<br>Trade Value=%{y}<extra></extra>","legendgroup":"Feathers and down, prepared; and articles made of feather or of down; artificial flowers; articles of human hair","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Feathers and down, prepared; and articles made of feather or of down; artificial flowers; articles of human hair","offsetgroup":"Feathers and down, prepared; and articles made of feather or of down; artificial flowers; articles of human hair","orientation":"v","showlegend":true,"textposition":"auto","x":["Feathers and down, prepared; and articles made of feather or of down; artificial flowers; articles of human hair"],"xaxis":"x","y":[8180621653.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"HS2=%{x}<br>Trade Value=%{y}<extra></extra>","legendgroup":"Footwear; gaiters and the like; parts of such articles","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Footwear; gaiters and the like; parts of such articles","offsetgroup":"Footwear; gaiters and the like; parts of such articles","orientation":"v","showlegend":true,"textposition":"auto","x":["Footwear; gaiters and the like; parts of such articles"],"xaxis":"x","y":[149055821999.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"HS2=%{x}<br>Trade Value=%{y}<extra></extra>","legendgroup":"Headgear and parts thereof","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Headgear and parts thereof","offsetgroup":"Headgear and parts thereof","orientation":"v","showlegend":true,"textposition":"auto","x":["Headgear and parts thereof"],"xaxis":"x","y":[10623492891.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"HS2=%{x}<br>Trade Value=%{y}<extra></extra>","legendgroup":"Umbrellas, sun umbrellas, walking-sticks, seat sticks, whips, riding crops; and parts thereof","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Umbrellas, sun umbrellas, walking-sticks, seat sticks, whips, riding crops; and parts thereof","offsetgroup":"Umbrellas, sun umbrellas, walking-sticks, seat sticks, whips, riding crops; and parts thereof","orientation":"v","showlegend":true,"textposition":"auto","x":["Umbrellas, sun umbrellas, walking-sticks, seat sticks, whips, riding crops; and parts thereof"],"xaxis":"x","y":[3592043977.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f ...

# %%
dt = dt[["HS2", 'Trade Value']].groupby("HS2").sum()
dt = dt.reset_index()
fig = go.Figure(data=[go.Pie(labels=dt["HS2"], values=dt['Trade Value'], hole=.5)])
fig.update_layout(height=500, width=1400, title_text='Trade Percentage for Footwear and Headwear Products') 
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="c1396749-dd4b-4e79-8d2d-6e984d3c13e6" class="plotly-graph-div" style="height:500px; width:1400px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c1396749-dd4b-4e79-8d2d-6e984d3c13e6")) {                    Plotly.newPlot(                        "c1396749-dd4b-4e79-8d2d-6e984d3c13e6",                        [{"hole":0.5,"labels":["Feathers and down, prepared; and articles made of feather or of down; artificial flowers; articles of human hair","Footwear; gaiters and the like; parts of such articles","Headgear and parts thereof","Umbrellas, sun umbrellas, walking-sticks, seat sticks, whips, riding crops; and parts thereof"],"values":[8180621653.0,149055821999.0,10623492891.0,3592043977.0],"type":"pie"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks": ...

# %% [markdown]
# ### **GROUP BY SECTION: Stone and Glass**

# %%
dt = data[["Section", 'HS2', 'Trade Value']]
dt = dt[dt["Section"] == 'Stone And Glass']
dt = dt.groupby(['HS2']).sum().reset_index()
dt
# Out:
#                                                  HS2   Trade Value
# 0                                   Ceramic products  5.629596e+10
# 1                                Glass and glassware  7.591627e+10
# 2  Stone, plaster, cement, asbestos, mica or simi...  5.258255e+10

# %%
def barplot(data):
  fig = px.bar(dt, x=dt.HS2, y=dt['Trade Value'], color=dt.HS2)
  fig.update_xaxes(title_text = "Stone and Glass Products", rangeslider_visible=False, showline=True, linewidth=2, linecolor='black', mirror=True)
  fig.update_yaxes(title_text = 'Trade Value', showline=True, linewidth=2, linecolor='black', mirror=True)
  # fig.update_traces(marker_color='rgb(158,202,225)', marker_line_color='rgb(8,48,107)', marker_line_width=1.5, opacity=0.6)
  fig.update_layout(height=700, width=1400, title_text='Trade Values for Stone and Glass Products') 
  fig.show()

barplot(dt)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="54008814-a1c2-4301-9f97-cfec043333aa" class="plotly-graph-div" style="height:700px; width:1400px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("54008814-a1c2-4301-9f97-cfec043333aa")) {                    Plotly.newPlot(                        "54008814-a1c2-4301-9f97-cfec043333aa",                        [{"alignmentgroup":"True","hovertemplate":"HS2=%{x}<br>Trade Value=%{y}<extra></extra>","legendgroup":"Ceramic products","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Ceramic products","offsetgroup":"Ceramic products","orientation":"v","showlegend":true,"textposition":"auto","x":["Ceramic products"],"xaxis":"x","y":[56295958658.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"HS2=%{x}<br>Trade Value=%{y}<extra></extra>","legendgroup":"Glass and glassware","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Glass and glassware","offsetgroup":"Glass and glassware","orientation":"v","showlegend":true,"textposition":"auto","x":["Glass and glassware"],"xaxis":"x","y":[75916274558.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"HS2=%{x}<br>Trade Value=%{y}<extra></extra>","legendgroup":"Stone, plaster, cement, asbestos, mica or similar materials; articles thereof","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Stone, plaster, cement, asbestos, mica or similar materials; articles thereof","offsetgroup":"Stone, plaster, cement, asbestos, mica or similar materials; articles thereof","orientation":"v","showlegend":true,"textposition":"auto","x":["Stone, plaster, cement, asbestos, mica or similar materials; articles thereof"],"xaxis":"x","y":[52582545306.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"t ...

# %%
dt = dt[["HS2", 'Trade Value']].groupby("HS2").sum()
dt = dt.reset_index()
fig = go.Figure(data=[go.Pie(labels=dt["HS2"], values=dt['Trade Value'], hole=.5)])
fig.update_layout(height=500, width=1400, title_text='Trade Percentage for Stone and Glass Products') 
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="57ba4535-93f7-4d45-aea5-34195ab52c90" class="plotly-graph-div" style="height:500px; width:1400px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("57ba4535-93f7-4d45-aea5-34195ab52c90")) {                    Plotly.newPlot(                        "57ba4535-93f7-4d45-aea5-34195ab52c90",                        [{"hole":0.5,"labels":["Ceramic products","Glass and glassware","Stone, plaster, cement, asbestos, mica or similar materials; articles thereof"],"values":[56295958658.0,75916274558.0,52582545306.0],"type":"pie"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{ ...

# %% [markdown]
# ### **GROUP BY SECTION: Precious Metals**

# %%
dt = data[["Section", 'HS2', 'Trade Value']]
dt = dt[dt["Section"] == 'Precious Metals']
dt = dt.groupby(['HS2']).sum().reset_index()
dt
# Out:
#                                  HS2   Trade Value
# 0  Precious metals, gems and jewelry  6.539647e+11

# %%
dt = dt[["HS2", 'Trade Value']].groupby("HS2").sum()
dt = dt.reset_index()
fig = go.Figure(data=[go.Pie(labels=dt["HS2"], values=dt['Trade Value'], hole=.5)])
fig.update_layout(height=500, width=1400, title_text='Trade Percentage for Precious Metal Products') 
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="43ceb945-9745-4f49-a370-87ba963bba4e" class="plotly-graph-div" style="height:500px; width:1400px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("43ceb945-9745-4f49-a370-87ba963bba4e")) {                    Plotly.newPlot(                        "43ceb945-9745-4f49-a370-87ba963bba4e",                        [{"hole":0.5,"labels":["Precious metals, gems and jewelry"],"values":[653964673538.0],"type":"pie"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattercarpet"}],"scattergeo":[{"marker":{"colorbar":{"outline ...

# %% [markdown]
# ### **GROUP BY SECTION: Metals**

# %%
dt = data[["Section", 'HS2', 'Trade Value']]
dt = dt[dt["Section"] == 'Metals']
dt = dt.groupby(['HS2']).sum().reset_index()
dt
# Out:
#                                              HS2   Trade Value
# 0                 Aluminium and articles thereof  1.787256e+11
# 1                    Copper and articles thereof  1.528216e+11
# 2                                 Iron and steel  3.799608e+11
# 3                         Iron or steel articles  3.065532e+11
# 4                      Lead and articles thereof  8.145299e+09
# 5    Metal; miscellaneous products of base metal  7.220546e+10
# 6   Metals; n.e.s., cermets and articles thereof  2.075540e+10
# 7                    Nickel and articles thereof  3.111694e+10
# 8                          Tin; articles thereof  5.265574e+09
# 9                              Tools and cutlery  6.580787e+10
# 10                     Zinc and articles thereof  1.874409e+10

# %%
def barplot(data):
  fig = px.bar(dt, x=dt.HS2, y=dt['Trade Value'], color=dt.HS2)
  fig.update_xaxes(title_text = "Metal Products", rangeslider_visible=True, showline=True, linewidth=2, linecolor='black', mirror=True)
  fig.update_yaxes(title_text = 'Trade Value', showline=True, linewidth=2, linecolor='black', mirror=True)
  # fig.update_traces(marker_color='rgb(158,202,225)', marker_line_color='rgb(8,48,107)', marker_line_width=1.5, opacity=0.6)
  fig.update_layout(height=700, width=1400, title_text='Trade Values for Metal Products') 
  fig.show()

barplot(dt)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="fca5e2ec-2206-4ee0-ae4e-14108fde5389" class="plotly-graph-div" style="height:700px; width:1400px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fca5e2ec-2206-4ee0-ae4e-14108fde5389")) {                    Plotly.newPlot(                        "fca5e2ec-2206-4ee0-ae4e-14108fde5389",                        [{"alignmentgroup":"True","hovertemplate":"HS2=%{x}<br>Trade Value=%{y}<extra></extra>","legendgroup":"Aluminium and articles thereof","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Aluminium and articles thereof","offsetgroup":"Aluminium and articles thereof","orientation":"v","showlegend":true,"textposition":"auto","x":["Aluminium and articles thereof"],"xaxis":"x","y":[178725566093.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"HS2=%{x}<br>Trade Value=%{y}<extra></extra>","legendgroup":"Copper and articles thereof","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Copper and articles thereof","offsetgroup":"Copper and articles thereof","orientation":"v","showlegend":true,"textposition":"auto","x":["Copper and articles thereof"],"xaxis":"x","y":[152821611235.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"HS2=%{x}<br>Trade Value=%{y}<extra></extra>","legendgroup":"Iron and steel","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Iron and steel","offsetgroup":"Iron and steel","orientation":"v","showlegend":true,"textposition":"auto","x":["Iron and steel"],"xaxis":"x","y":[379960776333.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"HS2=%{x}<br>Trade Value=%{y}<extra></extra>","legendgroup":"Iron or steel articles","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Iron or steel articles","offsetgroup":"Iron or steel articles","orientation":"v","showlegend":true,"textposition":"auto","x":["Iron or steel articles"],"xaxis":"x","y":[306553190714.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"HS2=%{x}<br>Trade Value=%{y}<extra></extra>","legendgroup":"Lead and articles thereof","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Lead and articles thereof","offsetgroup":"Lead and articles thereof","orientation":"v","showlegend":true,"textposition":"auto","x":["Lead and articles thereof"],"xaxis":"x","y":[8145299115.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"HS2=%{x}<br>Trade Value=%{y}<extra></extra>","legendgroup":"Metal; miscellaneous products of base metal","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Metal; miscellaneous products of base metal","offsetgroup":"Metal; miscellaneous products of base metal","orientation":"v","showlegend":true,"textposition":"auto","x":["Metal; miscellaneous products of base metal"],"xaxis":"x","y":[72205463728.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"HS2=%{x}<br>Trade Value=%{y}<extra></extra>","legendgroup":"Metals; n.e.s., cermets and articles thereof","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Metals; n.e.s., cermets and articles thereof","offsetgroup":"Metals; n.e.s., cermets and articles thereof","orientation":"v","showlegend":true,"textposition":"auto","x":["Metals; n.e.s., cermets and articles thereof"],"xaxis":"x","y":[20755401151.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"HS2=%{x}<br>Trade Value=%{y}<extra></extra>","legendgroup":"Nickel and articles thereof","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Nickel and articles thereof","offsetgroup":"Nickel and articles thereof","orientation":"v","showlegend":true,"textposition":"auto","x":["Nickel and articles thereof"],"xaxis":"x","y":[31116944507.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"HS2=%{x}<br>Tr ...

# %%
dt = dt[["HS2", 'Trade Value']].groupby("HS2").sum()
dt = dt.reset_index()
fig = go.Figure(data=[go.Pie(labels=dt["HS2"], values=dt['Trade Value'], hole=.5)])
fig.update_layout(height=500, width=1400, title_text='Trade Percentage for Metal Products') 
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="cf3511df-5370-4a4f-a04e-b2a02c7fe986" class="plotly-graph-div" style="height:500px; width:1400px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cf3511df-5370-4a4f-a04e-b2a02c7fe986")) {                    Plotly.newPlot(                        "cf3511df-5370-4a4f-a04e-b2a02c7fe986",                        [{"hole":0.5,"labels":["Aluminium and articles thereof","Copper and articles thereof","Iron and steel","Iron or steel articles","Lead and articles thereof","Metal; miscellaneous products of base metal","Metals; n.e.s., cermets and articles thereof","Nickel and articles thereof","Tin; articles thereof","Tools and cutlery","Zinc and articles thereof"],"values":[178725566093.0,152821611235.0,379960776333.0,306553190714.0,8145299115.0,72205463728.0,20755401151.0,31116944507.0,5265574468.0,65807866562.0,18744089913.0],"type":"pie"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"t ...

# %% [markdown]
# ### **GROUP BY SECTION: Machines**

# %%
dt = data[["Section", 'HS2', 'Trade Value']]
dt = dt[dt["Section"] == 'Machines']
dt = dt.groupby(['HS2']).sum().reset_index()
dt
# Out:
#                                   HS2   Trade Value
# 0  Electrical machinery and equipment  2.530573e+12
# 1            Machinery and appliances  2.173359e+12

# %%
def barplot(data):
  fig = px.bar(dt, x=dt.HS2, y=dt['Trade Value'], color=dt.HS2)
  fig.update_xaxes(title_text = "Machine Products", rangeslider_visible=False, showline=True, linewidth=2, linecolor='black', mirror=True)
  fig.update_yaxes(title_text = 'Trade Value', showline=True, linewidth=2, linecolor='black', mirror=True)
  # fig.update_traces(marker_color='rgb(158,202,225)', marker_line_color='rgb(8,48,107)', marker_line_width=1.5, opacity=0.6)
  fig.update_layout(height=700, width=1400, title_text='Trade Percentage for Machine Products') 
  fig.show()

barplot(dt)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="83200a76-9d0b-4b3c-9ead-a6923bf810a0" class="plotly-graph-div" style="height:700px; width:1400px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("83200a76-9d0b-4b3c-9ead-a6923bf810a0")) {                    Plotly.newPlot(                        "83200a76-9d0b-4b3c-9ead-a6923bf810a0",                        [{"alignmentgroup":"True","hovertemplate":"HS2=%{x}<br>Trade Value=%{y}<extra></extra>","legendgroup":"Electrical machinery and equipment","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Electrical machinery and equipment","offsetgroup":"Electrical machinery and equipment","orientation":"v","showlegend":true,"textposition":"auto","x":["Electrical machinery and equipment"],"xaxis":"x","y":[2530572805494.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"HS2=%{x}<br>Trade Value=%{y}<extra></extra>","legendgroup":"Machinery and appliances","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Machinery and appliances","offsetgroup":"Machinery and appliances","orientation":"v","showlegend":true,"textposition":"auto","x":["Machinery and appliances"],"xaxis":"x","y":[2173358755832.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.44 ...

# %%
dt = dt[["HS2", 'Trade Value']].groupby("HS2").sum()
dt = dt.reset_index()
fig = go.Figure(data=[go.Pie(labels=dt["HS2"], values=dt['Trade Value'], hole=.5)])
fig.update_layout(height=500, width=1400, title_text='Trade Percentage for Machine Products') 
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="f911913c-82de-4d72-a82b-91ee466725f2" class="plotly-graph-div" style="height:500px; width:1400px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f911913c-82de-4d72-a82b-91ee466725f2")) {                    Plotly.newPlot(                        "f911913c-82de-4d72-a82b-91ee466725f2",                        [{"hole":0.5,"labels":["Electrical machinery and equipment","Machinery and appliances"],"values":[2530572805494.0,2173358755832.0],"type":"pie"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattercarpet"}], ...

# %% [markdown]
# ### **GROUP BY SECTION: Instruments**

# %%
dt = data[["Section", 'HS2', 'Trade Value']]
dt = dt[dt["Section"] == 'Instruments']
dt = dt.groupby(['HS2']).sum().reset_index()
dt
# Out:
#                          HS2   Trade Value
# 0         Clocks and watches  4.693964e+10
# 1  Instruments and apparatus  6.413718e+11
# 2        Musical instruments  7.433170e+09

# %%
def barplot(data):
  fig = px.bar(dt, x=dt.HS2, y=dt['Trade Value'], color=dt.HS2)
  fig.update_xaxes(title_text = "Instrumental Products", rangeslider_visible=False, showline=True, linewidth=2, linecolor='black', mirror=True)
  fig.update_yaxes(title_text = 'Trade Value', showline=True, linewidth=2, linecolor='black', mirror=True)
  # fig.update_traces(marker_color='rgb(158,202,225)', marker_line_color='rgb(8,48,107)', marker_line_width=1.5, opacity=0.6)
  fig.update_layout(height=500, width=1400, title_text='Trade Values for Instrumental Products') 
  fig.show()

barplot(dt)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="a5a38657-dc93-4846-9255-f580cad00942" class="plotly-graph-div" style="height:500px; width:1400px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a5a38657-dc93-4846-9255-f580cad00942")) {                    Plotly.newPlot(                        "a5a38657-dc93-4846-9255-f580cad00942",                        [{"alignmentgroup":"True","hovertemplate":"HS2=%{x}<br>Trade Value=%{y}<extra></extra>","legendgroup":"Clocks and watches","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Clocks and watches","offsetgroup":"Clocks and watches","orientation":"v","showlegend":true,"textposition":"auto","x":["Clocks and watches"],"xaxis":"x","y":[46939640868.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"HS2=%{x}<br>Trade Value=%{y}<extra></extra>","legendgroup":"Instruments and apparatus","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Instruments and apparatus","offsetgroup":"Instruments and apparatus","orientation":"v","showlegend":true,"textposition":"auto","x":["Instruments and apparatus"],"xaxis":"x","y":[641371812061.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"HS2=%{x}<br>Trade Value=%{y}<extra></extra>","legendgroup":"Musical instruments","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Musical instruments","offsetgroup":"Musical instruments","orientation":"v","showlegend":true,"textposition":"auto","x":["Musical instruments"],"xaxis":"x","y":[7433170452.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.66 ...

# %%
dt = dt[["HS2", 'Trade Value']].groupby("HS2").sum()
dt = dt.reset_index()
fig = go.Figure(data=[go.Pie(labels=dt["HS2"], values=dt['Trade Value'], hole=.5)])
fig.update_layout(height=500, width=1400, title_text='Trade Percentage for  Steel Products') 
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="465d9c76-5117-48a9-a703-9f50406286d5" class="plotly-graph-div" style="height:500px; width:1400px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("465d9c76-5117-48a9-a703-9f50406286d5")) {                    Plotly.newPlot(                        "465d9c76-5117-48a9-a703-9f50406286d5",                        [{"hole":0.5,"labels":["Clocks and watches","Instruments and apparatus","Musical instruments"],"values":[46939640868.0,641371812061.0,7433170452.0],"type":"pie"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":" ...

# %% [markdown]
# ### **GROUP BY SECTION: Miscellaneous**

# %%
dt = data[["Section", 'HS2', 'Trade Value']]
dt = dt[dt["Section"] == 'Miscellaneous']
dt = dt.groupby(['HS2']).sum().reset_index()
dt
# Out:
#                                    HS2   Trade Value
# 0                            Furniture  2.568719e+11
# 1  Miscellaneous manufactured articles  3.591037e+10
# 2                       Toys and games  1.221823e+11

# %%
dt = dt[["HS2", 'Trade Value']].groupby("HS2").sum()
dt = dt.reset_index()
fig = go.Figure(data=[go.Pie(labels=dt["HS2"], values=dt['Trade Value'], hole=.5)])
fig.update_layout(height=500, width=1400, title_text='Trade Percentage for Miscellaneous Products') 
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="76aae8d9-53c2-4e1e-93b4-520286573be9" class="plotly-graph-div" style="height:500px; width:1400px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("76aae8d9-53c2-4e1e-93b4-520286573be9")) {                    Plotly.newPlot(                        "76aae8d9-53c2-4e1e-93b4-520286573be9",                        [{"hole":0.5,"labels":["Furniture","Miscellaneous manufactured articles","Toys and games"],"values":[256871887364.0,35910369723.0,122182295055.0],"type":"pie"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"sc ...

# %% [markdown]
# ### **GROUP BY SECTION: Art and Antiques**

# %%
dt = data[["Section", 'HS2', 'Trade Value']]
dt = dt[dt["Section"] == 'Arts and Antiques']
dt = dt.groupby(['HS2']).sum().reset_index()
dt
# Out:
#                                              HS2   Trade Value
# 0  Works of art; collectors' pieces and antiques  2.699257e+10

# %%
dt = dt[["HS2", 'Trade Value']].groupby("HS2").sum()
dt = dt.reset_index()
fig = go.Figure(data=[go.Pie(labels=dt["HS2"], values=dt['Trade Value'], hole=.5)])
fig.update_layout(height=500, width=1400, title_text='Trade Percentage for Art and Antiques Products') 
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="8485e2c6-fa51-46ba-a643-178f014fae0a" class="plotly-graph-div" style="height:500px; width:1400px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8485e2c6-fa51-46ba-a643-178f014fae0a")) {                    Plotly.newPlot(                        "8485e2c6-fa51-46ba-a643-178f014fae0a",                        [{"hole":0.5,"labels":["Works of art; collectors' pieces and antiques"],"values":[26992566174.0],"type":"pie"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattercarpet"}],"scattergeo":[{"marker":{"colorbar ...

# %% [markdown]
# ## **GROUP BY ITEMS**

# %%
dt = data[['HS4', 'Trade Value']]
"""dt = dt.melt(id_vars=["Item - (Export Quantity in '000 Tonnes)"], var_name = "Years", value_name = "Production")
dt.sort_values(["Item - (Export Quantity in '000 Tonnes)", 'Years'], inplace = True)"""
dt
# Out:
#                     HS4   Trade Value
# 0                Horses  3.316602e+09
# 1                Bovine  9.050742e+09
# 2                  Pigs  4.180847e+09
# 3       Sheep and Goats  1.732222e+09
# 4               Poultry  3.200487e+09
# ...                 ...           ...
# 1212             Prints  4.946755e+08
# 1213         Sculptures  4.184434e+09
# 1214     Revenue Stamps  1.308665e+08
# 1215  Collector's Items  1.489845e+09
# 1216           Antiques  3.461361e+09
#
# [1217 rows x 2 columns]

# %%
def barplot(data):
  fig = px.bar(data, x=dt.HS4, y=dt['Trade Value'], color=dt.HS4)
  fig.update_xaxes(title_text = "Steel Products", rangeslider_visible=True, showline=True, linewidth=2, linecolor='black', mirror=True)
  fig.update_yaxes(title_text = 'Trade Value', showline=True, linewidth=2, linecolor='black', mirror=True)
  # fig.update_traces(marker_color='rgb(158,202,225)', marker_line_color='rgb(8,48,107)', marker_line_width=1.5, opacity=0.6)
  fig.update_layout(height=900, width=1400, title_text='Trade Values for Steel Related Products') 
  fig.show()

barplot(dt)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="8ffdec81-4638-4ff1-ad19-21c1ddf2b0f2" class="plotly-graph-div" style="height:900px; width:1400px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8ffdec81-4638-4ff1-ad19-21c1ddf2b0f2")) {                    Plotly.newPlot(                        "8ffdec81-4638-4ff1-ad19-21c1ddf2b0f2",                        [{"alignmentgroup":"True","hovertemplate":"HS4=%{x}<br>Trade Value=%{y}<extra></extra>","legendgroup":"Horses","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Horses","offsetgroup":"Horses","orientation":"v","showlegend":true,"textposition":"auto","x":["Horses"],"xaxis":"x","y":[3316601863.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"HS4=%{x}<br>Trade Value=%{y}<extra></extra>","legendgroup":"Bovine","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Bovine","offsetgroup":"Bovine","orientation":"v","showlegend":true,"textposition":"auto","x":["Bovine"],"xaxis":"x","y":[9050742117.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"HS4=%{x}<br>Trade Value=%{y}<extra></extra>","legendgroup":"Pigs","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Pigs","offsetgroup":"Pigs","orientation":"v","showlegend":true,"textposition":"auto","x":["Pigs"],"xaxis":"x","y":[4180847046.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"HS4=%{x}<br>Trade Value=%{y}<extra></extra>","legendgroup":"Sheep and Goats","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Sheep and Goats","offsetgroup":"Sheep and Goats","orientation":"v","showlegend":true,"textposition":"auto","x":["Sheep and Goats"],"xaxis":"x","y":[1732222449.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"HS4=%{x}<br>Trade Value=%{y}<extra></extra>","legendgroup":"Poultry","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Poultry","offsetgroup":"Poultry","orientation":"v","showlegend":true,"textposition":"auto","x":["Poultry"],"xaxis":"x","y":[3200486732.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"HS4=%{x}<br>Trade Value=%{y}<extra></extra>","legendgroup":"Other Animals","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Other Animals","offsetgroup":"Other Animals","orientation":"v","showlegend":true,"textposition":"auto","x":["Other Animals"],"xaxis":"x","y":[1228951066.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"HS4=%{x}<br>Trade Value=%{y}<extra></extra>","legendgroup":"Bovine Meat","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Bovine Meat","offsetgroup":"Bovine Meat","orientation":"v","showlegend":true,"textposition":"auto","x":["Bovine Meat"],"xaxis":"x","y":[23984686436.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"HS4=%{x}<br>Trade Value=%{y}<extra></extra>","legendgroup":"Frozen Bovine Meat","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Frozen Bovine Meat","offsetgroup":"Frozen Bovine Meat","orientation":"v","showlegend":true,"textposition":"auto","x":["Frozen Bovine Meat"],"xaxis":"x","y":[28214398001.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"HS4=%{x}<br>Trade Value=%{y}<extra></extra>","legendgroup":"Pig Meat","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Pig Meat","offsetgroup":"Pig Meat","orientation":"v","showlegend":true,"textposition":"auto","x":["Pig Meat"],"xaxis":"x","y":[33079859881.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"HS4=%{x}<br>Trade Value=%{y}<extra></extra>","legendgroup":"Sheep and Goat Meat","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"Sheep and Goat Meat","offsetgroup":"Sheep and Goat Meat","orientation":"v","showlegend":true,"textposition":"auto","x":["Sheep and Goat Meat"],"xaxis" ...

# %%
"""dt = dt[["HS4", 'Trade Value']].groupby("HS4").sum()
dt = dt.reset_index()
fig = go.Figure(data=[go.Pie(labels=dt["HS4"], values=dt['Trade Value'], hole=.5)])
fig.update_layout(height=1000, width=1400, title_text='Percentage Distribution of Trade Values for Steel Related Products)') 
fig.show()"""
# Out:
# 'dt = dt[["HS4", \'Trade Value\']].groupby("HS4").sum()\ndt = dt.reset_index()\nfig = go.Figure(data=[go.Pie(labels=dt["HS4"], values=dt[\'Trade Value\'], hole=.5)])\nfig.update_layout(height=1000, width=1400, title_text=\'Percentage Distribution of Trade Values for Steel Related Products)\') \nfig.show()'

# %% [markdown]
# ## **GROUP BY HS2**

# %%
dt = data[["HS2", 'Trade Value']]
dt.groupby(['HS2']).sum().reset_index()
# Out:
#                                                   HS2   Trade Value
# 0              Aircraft, spacecraft and parts thereof  2.533680e+11
# 1   Albuminoidal substances; modified starches; gl...  3.026782e+10
# 2                      Aluminium and articles thereof  1.787256e+11
# 3   Animal or vegetable fats and oils and their cl...  1.004449e+11
# 4   Animal originated products; not elsewhere spec...  1.146496e+10
# ..                                                ...           ...
# 91           Wood and articles of wood; wood charcoal  1.382003e+11
# 92  Wool, fine or coarse animal hair; horsehair ya...  1.281346e+10
# 93      Works of art; collectors' pieces and antiques  2.699257e+10
# 94                                      Woven fabrics  1.198655e+10
# 95                          Zinc and articles thereof  1.874409e+10
#
# [96 rows x 2 columns]

# %%
def barplot(data):
  fig = px.bar(data, x=dt.HS2, y=dt['Trade Value'])
  fig.update_xaxes(title_text = "Steel Products", rangeslider_visible=False, showline=True, linewidth=2, linecolor='black', mirror=True)
  fig.update_yaxes(title_text = 'Trade Value', showline=True, linewidth=2, linecolor='black', mirror=True)
  # fig.update_traces(marker_color='rgb(158,202,225)', marker_line_color='rgb(8,48,107)', marker_line_width=1.5, opacity=0.6)
  fig.update_layout(height=2000, width=1400, title_text='Trade Values for Steel Related Products') 
  fig.show()

barplot(dt)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="89dc875a-9e00-4038-9c9f-cd1df15b6223" class="plotly-graph-div" style="height:2000px; width:1400px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("89dc875a-9e00-4038-9c9f-cd1df15b6223")) {                    Plotly.newPlot(                        "89dc875a-9e00-4038-9c9f-cd1df15b6223",                        [{"alignmentgroup":"True","hovertemplate":"HS2=%{x}<br>Trade Value=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Live animals","Live animals","Live animals","Live animals","Live animals","Live animals","Meat and edible meat offal","Meat and edible meat offal","Meat and edible meat offal","Meat and edible meat offal","Meat and edible meat offal","Meat and edible meat offal","Meat and edible meat offal","Meat and edible meat offal","Meat and edible meat offal","Meat and edible meat offal","Fish and crustaceans, molluscs and other aquatic invertebrates","Fish and crustaceans, molluscs and other aquatic invertebrates","Fish and crustaceans, molluscs and other aquatic invertebrates","Fish and crustaceans, molluscs and other aquatic invertebrates","Fish and crustaceans, molluscs and other aquatic invertebrates","Fish and crustaceans, molluscs and other aquatic invertebrates","Fish and crustaceans, molluscs and other aquatic invertebrates","Dairy products and other edible products of animal origin","Dairy products and other edible products of animal origin","Dairy products and other edible products of animal origin","Dairy products and other edible products of animal origin","Dairy products and other edible products of animal origin","Dairy products and other edible products of animal origin","Dairy products and other edible products of animal origin","Dairy products and other edible products of animal origin","Dairy products and other edible products of animal origin","Dairy products and other edible products of animal origin","Animal originated products; not elsewhere specified or included","Animal originated products; not elsewhere specified or included","Animal originated products; not elsewhere specified or included","Animal originated products; not elsewhere specified or included","Animal originated products; not elsewhere specified or included","Animal originated products; not elsewhere specified or included","Animal originated products; not elsewhere specified or included","Animal originated products; not elsewhere specified or included","Animal originated products; not elsewhere specified or included","Trees and other live plants","Trees and other live plants","Trees and other live plants","Trees and other live plants","Vegetables and certain roots and tubers; edible","Vegetables and certain roots and tubers; edible","Vegetables and certain roots and tubers; edible","Vegetables and certain roots and tubers; edible","Vegetables and certain roots and tubers; edible","Vegetables and certain roots and tubers; edible","Vegetables and certain roots and tubers; edible","Vegetables and certain roots and tubers; edible","Vegetables and certain roots and tubers; edible","Vegetables and certain roots and tubers; edible","Vegetables and certain roots and tubers; edible","Vegetables and certain roots and tubers; edible","Vegetables and certain roots and tubers; edible","Vegetables and certain roots and tubers; edible","Fruit and nuts, edible; peel of citrus fruit or melons","Fruit and nuts, edible; peel of citrus fruit or melons","Fruit and nuts, edible; peel of citrus fruit or melons","Fruit and nuts, edible; peel of citrus fruit or melons","Fruit and nuts, edible; peel of citrus fruit or melons","Fruit and nuts, edible; peel of citrus fruit or melons","Fruit and n ...

# %%
"""dt = dt[["HS2", 'Trade Value']].groupby("HS2").sum()
dt = dt.reset_index()
fig = go.Figure(data=[go.Pie(labels=dt["HS2"], values=dt['Trade Value'], hole=.5)])
fig.update_layout(height=1000, width=1400, title_text='Percentage Distribution of Trade Values for Steel Related Products)') 
fig.show()"""
# Out:
# 'dt = dt[["HS2", \'Trade Value\']].groupby("HS2").sum()\ndt = dt.reset_index()\nfig = go.Figure(data=[go.Pie(labels=dt["HS2"], values=dt[\'Trade Value\'], hole=.5)])\nfig.update_layout(height=1000, width=1400, title_text=\'Percentage Distribution of Trade Values for Steel Related Products)\') \nfig.show()'
