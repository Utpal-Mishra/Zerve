# %% [markdown]
# <a href="https://colab.research.google.com/github/Utpal-Mishra/Zerve/blob/main/ZerveSteelExport.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# DATA SOURCE: https://oec.world/en/profile/hs92/steel-bars?countryComparisonFlowSelector=Imports&countryComparisonMeasureSelector=Growth%20Rate&countryComparisonRankSelector=Top&cumulativeMarketShareSelected=share&redirect=true&yearSelector2=tradeYear2&yearSelector4=tradeYear1

# %% [markdown]
# ### Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objects as go
from datetime import datetime as dt

# %% [markdown]
# ### Import Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## **Import Dependencies**

# %% [markdown]
# ### Import File

# %%
import pandas as pd
path = '/content/drive/MyDrive/Jobs/Zerve/Top-10-Exporters-Countries-of-Steel-Bars-by-percentage-of-total-exports.csv'
data = pd.read_csv(path)
print("Data Shape: ", data.shape)
data
# Out:
# Data Shape:  (250, 8)
#        Country Country ID  ...  Gross Trade Value  Product Percentage
# 0      Senegal      afsen  ...          502129440            0.000000
# 1      Senegal      afsen  ...          685037177            0.000000
# 2      Senegal      afsen  ...          656132290            0.000000
# 3      Senegal      afsen  ...          827657330            0.000000
# 4      Senegal      afsen  ...          824827713            0.000000
# ..         ...        ...  ...                ...                 ...
# 245  Argentina      saarg  ...        57741672348            0.001243
# 246  Argentina      saarg  ...        58949194554            0.000534
# 247  Argentina      saarg  ...        59534201852            0.001946
# 248  Argentina      saarg  ...        61239046060            0.014956
# 249  Argentina      saarg  ...        63951119428            0.042173
#
# [250 rows x 8 columns]

# %% [markdown]
# ## **Exploratory Data Analysis**

# %% [markdown]
# ### Check Null Values

# %%
if data.isna().sum().sum() != 0:
  print("EMPTY VALUES EXIST IN THE DATA\n\nFollowing is a list of feature variable with their respective null values count:", data.isna().sum())

# %%
data = data.sort_values(['Year', 'Country'])
data = data[['Year', 'Country', 'Product Trade Value', 'Product Growth', 'Product Growth Rate', 'Gross Trade Value', 'Product Percentage']]
data.head()

# %% [markdown]
# # **Visualization**

# %%
def barplot(data):
  fig = px.bar(data, x=data.Country, y=data['Product Trade Value'], animation_frame=data.Year, color=data.Country)
  fig.update_xaxes(title_text = "Countries", rangeslider_visible=False, showline=True, linewidth=2, linecolor='black', mirror=True)
  fig.update_yaxes(title_text = 'Trade Value', showline=True, linewidth=2, linecolor='black', mirror=True)
  fig.update_layout(height=600, width=1400, title_text='Top 10 Countries Product Trade Values') 
  fig.show()

barplot(data)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
def barplot(data):
  fig = px.bar(data, x=data.Country, y=data['Gross Trade Value'], animation_frame=data.Year, color=data.Country)
  fig.update_xaxes(title_text = "Countries", rangeslider_visible=False, showline=True, linewidth=2, linecolor='black', mirror=True)
  fig.update_yaxes(title_text = 'Gross Trade Value', showline=True, linewidth=2, linecolor='black', mirror=True)
  fig.update_layout(height=600, width=1400, title_text='Top 10 Countries Gross Trade Values') 
  fig.show()

barplot(data)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
def barplot(data):
  fig = px.bar(data, x=data.Country, y=data['Product Growth'], animation_frame=data.Year, color=data.Country)
  fig.update_xaxes(title_text = "Countries", rangeslider_visible=False, showline=True, linewidth=2, linecolor='black', mirror=True)
  fig.update_yaxes(title_text = 'Product Growth Value', showline=True, linewidth=2, linecolor='black', mirror=True)
  fig.update_layout(height=600, width=1400, title_text='Top 10 Countries Product Growth Value') 
  fig.show()

barplot(data)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
def barplot(data):
  fig = px.bar(data, x=data.Country, y=data['Product Growth Rate'], animation_frame=data.Year, color=data.Country)
  fig.update_xaxes(title_text = "Countries", rangeslider_visible=False, showline=True, linewidth=2, linecolor='black', mirror=True)
  fig.update_yaxes(title_text = 'Product Growth Rate', showline=True, linewidth=2, linecolor='black', mirror=True)
  fig.update_layout(height=600, width=1400, title_text='Top 10 Countries Product Growth Rate')
  fig.show()

barplot(data)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
