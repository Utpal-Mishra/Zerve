# %% [markdown]
# <a href="https://colab.research.google.com/github/Utpal-Mishra/Zerve/blob/main/ZerveSteelTariff.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# DATA SOURCE: https://oec.world/en/profile/hs92/steel-bars?countryComparisonFlowSelector=Imports&countryComparisonMeasureSelector=Growth%20Rate&countryComparisonRankSelector=Top&cumulativeMarketShareSelected=share&redirect=true&yearSelector2=tradeYear2&yearSelector4=tradeYear1

# %% [markdown]
# ### Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import plotly.express as px
import plotly.graph_objects as go
from datetime import datetime as dt

# %% [markdown]
# ### Import Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## **Import Dependencies**

# %% [markdown]
# ### Import File

# %%
import pandas as pd
path = '/content/drive/MyDrive/Jobs/Zerve/World-Tariffs-for-Steel-Bars-Simple-Average.csv'
data = pd.read_csv(path)
print("Data Shape: ", data.shape)
data
# Out:
# Data Shape:  (185, 3)
#      Year              Country     Tariff
# 0    2002         Turkmenistan   0.000000
# 1    2006                Libya   0.000000
# 2    2013             Barbados   4.211538
# 3    2013                Syria   0.919231
# 4    2013  Trinidad and Tobago   4.730769
# ..    ...                  ...        ...
# 180  2019        United States   0.000000
# 181  2019              Uruguay  13.343077
# 182  2019            Venezuela  12.636615
# 183  2019              Vietnam   0.000000
# 184  2019    Wallis and Futuna   4.938462
#
# [185 rows x 3 columns]

# %% [markdown]
# ## **Exploratory Data Analysis**

# %% [markdown]
# ### Check Null Values

# %%
if data.isna().sum().sum() != 0:
  print("EMPTY VALUES EXIST IN THE DATA\n\nFollowing is a list of feature variable with their respective null values count:", data.isna().sum())

# %% [markdown]
# # **Visualization**

# %% [markdown]
# ### 2002

# %%
dt = data[data['Year'] == 2002]
dt = dt.groupby(['Country']).sum().reset_index()
dt
# Out:
#         Country  Year  Tariff
# 0  Turkmenistan  2002     0.0

# %%
fig = px.scatter(dt, x=dt.Country, y=dt.Tariff, color=dt.Country, size=dt.Tariff)
fig.update_xaxes(title_text = "Country", rangeslider_visible=False, showline=True, linewidth=2, linecolor='black', mirror=True)
fig.update_yaxes(title_text = 'Tariff %', showline=True, linewidth=2, linecolor='black', mirror=True)
fig.update_layout(height=400, width=1000, title_text='Global Tariff % in 2002') 
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="28ec8ec4-db2c-49d6-bbf5-b54a45136897" class="plotly-graph-div" style="height:400px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("28ec8ec4-db2c-49d6-bbf5-b54a45136897")) {                    Plotly.newPlot(                        "28ec8ec4-db2c-49d6-bbf5-b54a45136897",                        [{"hovertemplate":"Country=%{x}<br>Tariff=%{marker.size}<extra></extra>","legendgroup":"Turkmenistan","marker":{"color":"#636efa","size":[0.0],"sizemode":"area","sizeref":0.0,"symbol":"circle"},"mode":"markers","name":"Turkmenistan","orientation":"v","showlegend":true,"x":["Turkmenistan"],"xaxis":"x","y":[0.0],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{" ...

# %% [markdown]
# ### 2003

# %%
dt = data[data['Year'] == 2006]
dt = dt.groupby(['Country']).sum().reset_index()
dt
# Out:
#   Country  Year  Tariff
# 0   Libya  2006     0.0

# %%
fig = px.scatter(dt, x=dt.Country, y=dt.Tariff, color=dt.Country, size=dt.Tariff)
fig.update_xaxes(title_text = "Country", rangeslider_visible=False, showline=True, linewidth=2, linecolor='black', mirror=True)
fig.update_yaxes(title_text = 'Tariff %', showline=True, linewidth=2, linecolor='black', mirror=True)
fig.update_layout(height=400, width=1000, title_text='Global Tariff % in 2006') 
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="22efc0d6-f862-4614-814f-b47994a4b7b1" class="plotly-graph-div" style="height:400px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("22efc0d6-f862-4614-814f-b47994a4b7b1")) {                    Plotly.newPlot(                        "22efc0d6-f862-4614-814f-b47994a4b7b1",                        [{"hovertemplate":"Country=%{x}<br>Tariff=%{marker.size}<extra></extra>","legendgroup":"Libya","marker":{"color":"#636efa","size":[0.0],"sizemode":"area","sizeref":0.0,"symbol":"circle"},"mode":"markers","name":"Libya","orientation":"v","showlegend":true,"x":["Libya"],"xaxis":"x","y":[0.0],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"tick ...

# %% [markdown]
# ### 2013

# %%
dt = data[data['Year'] == 2013]
dt = dt.groupby(['Country']).sum().reset_index()
dt
# Out:
#                Country  Year    Tariff
# 0             Barbados  2013  4.211538
# 1                Syria  2013  0.919231
# 2  Trinidad and Tobago  2013  4.730769

# %%
fig = px.scatter(dt, x=dt.Country, y=dt.Tariff, color=dt.Country, size=dt.Tariff)
fig.update_xaxes(title_text = "Country", rangeslider_visible=False, showline=True, linewidth=2, linecolor='black', mirror=True)
fig.update_yaxes(title_text = 'Tariff %', showline=True, linewidth=2, linecolor='black', mirror=True)
fig.update_layout(height=400, width=1000, title_text='Global Tariff % in 2013') 
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="f5f3ec9e-c5f0-48ff-b07a-314fb9e7d74c" class="plotly-graph-div" style="height:400px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f5f3ec9e-c5f0-48ff-b07a-314fb9e7d74c")) {                    Plotly.newPlot(                        "f5f3ec9e-c5f0-48ff-b07a-314fb9e7d74c",                        [{"hovertemplate":"Country=%{x}<br>Tariff=%{marker.size}<extra></extra>","legendgroup":"Cambodia","marker":{"color":"#636efa","size":[7.0],"sizemode":"area","sizeref":0.04903846155,"symbol":"circle"},"mode":"markers","name":"Cambodia","orientation":"v","showlegend":true,"x":["Cambodia"],"xaxis":"x","y":[7.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=%{x}<br>Tariff=%{marker.size}<extra></extra>","legendgroup":"Chad","marker":{"color":"#EF553B","size":[19.61538462],"sizemode":"area","sizeref":0.04903846155,"symbol":"circle"},"mode":"markers","name":"Chad","orientation":"v","showlegend":true,"x":["Chad"],"xaxis":"x","y":[19.61538462],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=%{x}<br>Tariff=%{marker.size}<extra></extra>","legendgroup":"Georgia","marker":{"color":"#00cc96","size":[0.0],"sizemode":"area","sizeref":0.04903846155,"symbol":"circle"},"mode":"markers","name":"Georgia","orientation":"v","showlegend":true,"x":["Georgia"],"xaxis":"x","y":[0.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=%{x}<br>Tariff=%{marker.size}<extra></extra>","legendgroup":"Haiti","marker":{"color":"#ab63fa","size":[0.0],"sizemode":"area","sizeref":0.04903846155,"symbol":"circle"},"mode":"markers","name":"Haiti","orientation":"v","showlegend":true,"x":["Haiti"],"xaxis":"x","y":[0.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=%{x}<br>Tariff=%{marker.size}<extra></extra>","legendgroup":"Jamaica","marker":{"color":"#FFA15A","size":[0.0],"sizemode":"area","sizeref":0.04903846155,"symbol":"circle"},"mode":"markers","name":"Jamaica","orientation":"v","showlegend":true,"x":["Jamaica"],"xaxis":"x","y":[0.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=%{x}<br>Tariff=%{marker.size}<extra></extra>","legendgroup":"Malaysia","marker":{"color":"#19d3f3","size":[5.0],"sizemode":"area","sizeref":0.04903846155,"symbol":"circle"},"mode":"markers","name":"Malaysia","orientation":"v","showlegend":true,"x":["Malaysia"],"xaxis":"x","y":[5.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=%{x}<br>Tariff=%{marker.size}<extra></extra>","legendgroup":"Moldova","marker":{"color":"#FF6692","size":[0.0],"sizemode":"area","sizeref":0.04903846155,"symbol":"circle"},"mode":"markers","name":"Moldova","orientation":"v","showlegend":true,"x":["Moldova"],"xaxis":"x","y":[0.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=%{x}<br>Tariff=%{marker.size}<extra></extra>","legendgroup":"Nigeria","marker":{"color":"#B6E880","size":[4.730769231],"sizemode":"area","sizeref":0.04903846155,"symbol":"circle"},"mode":"markers","name":"Nigeria","orientation":"v","showlegend":true,"x":["Nigeria"],"xaxis":"x","y":[4.730769231],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=%{x}<br>Tariff=%{marker.size}<extra></extra>","legendgroup":"Tunisia","marker":{"color":"#FF97FF","size":[0.0],"sizemode":"area","sizeref":0.04903846155,"symbol":"circle"},"mode":"markers","name":"Tunisia","orientation":"v","showlegend":true,"x":["Tunisia"],"xaxis":"x","y":[0.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=%{x}<br>Tariff=%{marker.size}<extra></extra>","legendgroup":"Zimbabwe","marker":{"color":"#FECB52","size":[4.557692308],"sizemode":"area","sizeref":0.04903846155,"symbol":"circle"},"mode":"markers","name":"Zimbabwe","orientation":"v","showlegend":true,"x":["Zimbabwe"],"xaxis":"x","y":[4.557692308],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"ba ...

# %% [markdown]
# ### 2015

# %%
dt = data[data['Year'] == 2015]
dt = dt.groupby(['Country']).sum().reset_index()
dt
# Out:
#                  Country  Year    Tariff
# 0              Guatemala  2015  0.000000
# 1                 Panama  2015  0.000000
# 2  Republic of the Congo  2015  4.903846
# 3               Thailand  2015  0.000000
# 4             Uzbekistan  2015  4.788462

# %%
fig = px.scatter(dt, x=dt.Country, y=dt.Tariff, color=dt.Country, size=dt.Tariff)
fig.update_xaxes(title_text = "Country", rangeslider_visible=False, showline=True, linewidth=2, linecolor='black', mirror=True)
fig.update_yaxes(title_text = 'Tariff %', showline=True, linewidth=2, linecolor='black', mirror=True)
fig.update_layout(height=400, width=1000, title_text='Global Tariff % in 2015') 
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="fb1a9e83-422d-4270-8ead-231f8283f830" class="plotly-graph-div" style="height:400px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fb1a9e83-422d-4270-8ead-231f8283f830")) {                    Plotly.newPlot(                        "fb1a9e83-422d-4270-8ead-231f8283f830",                        [{"hovertemplate":"Country=%{x}<br>Tariff=%{marker.size}<extra></extra>","legendgroup":"Cambodia","marker":{"color":"#636efa","size":[7.0],"sizemode":"area","sizeref":0.04903846155,"symbol":"circle"},"mode":"markers","name":"Cambodia","orientation":"v","showlegend":true,"x":["Cambodia"],"xaxis":"x","y":[7.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=%{x}<br>Tariff=%{marker.size}<extra></extra>","legendgroup":"Chad","marker":{"color":"#EF553B","size":[19.61538462],"sizemode":"area","sizeref":0.04903846155,"symbol":"circle"},"mode":"markers","name":"Chad","orientation":"v","showlegend":true,"x":["Chad"],"xaxis":"x","y":[19.61538462],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=%{x}<br>Tariff=%{marker.size}<extra></extra>","legendgroup":"Georgia","marker":{"color":"#00cc96","size":[0.0],"sizemode":"area","sizeref":0.04903846155,"symbol":"circle"},"mode":"markers","name":"Georgia","orientation":"v","showlegend":true,"x":["Georgia"],"xaxis":"x","y":[0.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=%{x}<br>Tariff=%{marker.size}<extra></extra>","legendgroup":"Haiti","marker":{"color":"#ab63fa","size":[0.0],"sizemode":"area","sizeref":0.04903846155,"symbol":"circle"},"mode":"markers","name":"Haiti","orientation":"v","showlegend":true,"x":["Haiti"],"xaxis":"x","y":[0.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=%{x}<br>Tariff=%{marker.size}<extra></extra>","legendgroup":"Jamaica","marker":{"color":"#FFA15A","size":[0.0],"sizemode":"area","sizeref":0.04903846155,"symbol":"circle"},"mode":"markers","name":"Jamaica","orientation":"v","showlegend":true,"x":["Jamaica"],"xaxis":"x","y":[0.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=%{x}<br>Tariff=%{marker.size}<extra></extra>","legendgroup":"Malaysia","marker":{"color":"#19d3f3","size":[5.0],"sizemode":"area","sizeref":0.04903846155,"symbol":"circle"},"mode":"markers","name":"Malaysia","orientation":"v","showlegend":true,"x":["Malaysia"],"xaxis":"x","y":[5.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=%{x}<br>Tariff=%{marker.size}<extra></extra>","legendgroup":"Moldova","marker":{"color":"#FF6692","size":[0.0],"sizemode":"area","sizeref":0.04903846155,"symbol":"circle"},"mode":"markers","name":"Moldova","orientation":"v","showlegend":true,"x":["Moldova"],"xaxis":"x","y":[0.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=%{x}<br>Tariff=%{marker.size}<extra></extra>","legendgroup":"Nigeria","marker":{"color":"#B6E880","size":[4.730769231],"sizemode":"area","sizeref":0.04903846155,"symbol":"circle"},"mode":"markers","name":"Nigeria","orientation":"v","showlegend":true,"x":["Nigeria"],"xaxis":"x","y":[4.730769231],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=%{x}<br>Tariff=%{marker.size}<extra></extra>","legendgroup":"Tunisia","marker":{"color":"#FF97FF","size":[0.0],"sizemode":"area","sizeref":0.04903846155,"symbol":"circle"},"mode":"markers","name":"Tunisia","orientation":"v","showlegend":true,"x":["Tunisia"],"xaxis":"x","y":[0.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=%{x}<br>Tariff=%{marker.size}<extra></extra>","legendgroup":"Zimbabwe","marker":{"color":"#FECB52","size":[4.557692308],"sizemode":"area","sizeref":0.04903846155,"symbol":"circle"},"mode":"markers","name":"Zimbabwe","orientation":"v","showlegend":true,"x":["Zimbabwe"],"xaxis":"x","y":[4.557692308],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"ba ...

# %% [markdown]
# ### 2016

# %%
dt = data[data['Year'] == 2016]
dt = dt.groupby(['Country']).sum().reset_index()
dt
# Out:
#     Country  Year     Tariff
# 0  Cambodia  2016   7.000000
# 1      Chad  2016  19.615385
# 2   Georgia  2016   0.000000
# 3     Haiti  2016   0.000000
# 4   Jamaica  2016   0.000000
# 5  Malaysia  2016   5.000000
# 6   Moldova  2016   0.000000
# 7   Nigeria  2016   4.730769
# 8   Tunisia  2016   0.000000
# 9  Zimbabwe  2016   4.557692

# %%
fig = px.scatter(dt, x=dt.Country, y=dt.Tariff, color=dt.Country, size=dt.Tariff)
fig.update_xaxes(title_text = "Country", rangeslider_visible=False, showline=True, linewidth=2, linecolor='black', mirror=True)
fig.update_yaxes(title_text = 'Tariff %', showline=True, linewidth=2, linecolor='black', mirror=True)
fig.update_layout(height=400, width=1000, title_text='Global Tariff % in 2016') 
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="f7c9d8c7-b249-4766-a5d3-cc40de5334a5" class="plotly-graph-div" style="height:400px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f7c9d8c7-b249-4766-a5d3-cc40de5334a5")) {                    Plotly.newPlot(                        "f7c9d8c7-b249-4766-a5d3-cc40de5334a5",                        [{"hovertemplate":"Country=%{x}<br>Tariff=%{marker.size}<extra></extra>","legendgroup":"Cambodia","marker":{"color":"#636efa","size":[7.0],"sizemode":"area","sizeref":0.04903846155,"symbol":"circle"},"mode":"markers","name":"Cambodia","orientation":"v","showlegend":true,"x":["Cambodia"],"xaxis":"x","y":[7.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=%{x}<br>Tariff=%{marker.size}<extra></extra>","legendgroup":"Chad","marker":{"color":"#EF553B","size":[19.61538462],"sizemode":"area","sizeref":0.04903846155,"symbol":"circle"},"mode":"markers","name":"Chad","orientation":"v","showlegend":true,"x":["Chad"],"xaxis":"x","y":[19.61538462],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=%{x}<br>Tariff=%{marker.size}<extra></extra>","legendgroup":"Georgia","marker":{"color":"#00cc96","size":[0.0],"sizemode":"area","sizeref":0.04903846155,"symbol":"circle"},"mode":"markers","name":"Georgia","orientation":"v","showlegend":true,"x":["Georgia"],"xaxis":"x","y":[0.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=%{x}<br>Tariff=%{marker.size}<extra></extra>","legendgroup":"Haiti","marker":{"color":"#ab63fa","size":[0.0],"sizemode":"area","sizeref":0.04903846155,"symbol":"circle"},"mode":"markers","name":"Haiti","orientation":"v","showlegend":true,"x":["Haiti"],"xaxis":"x","y":[0.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=%{x}<br>Tariff=%{marker.size}<extra></extra>","legendgroup":"Jamaica","marker":{"color":"#FFA15A","size":[0.0],"sizemode":"area","sizeref":0.04903846155,"symbol":"circle"},"mode":"markers","name":"Jamaica","orientation":"v","showlegend":true,"x":["Jamaica"],"xaxis":"x","y":[0.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=%{x}<br>Tariff=%{marker.size}<extra></extra>","legendgroup":"Malaysia","marker":{"color":"#19d3f3","size":[5.0],"sizemode":"area","sizeref":0.04903846155,"symbol":"circle"},"mode":"markers","name":"Malaysia","orientation":"v","showlegend":true,"x":["Malaysia"],"xaxis":"x","y":[5.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=%{x}<br>Tariff=%{marker.size}<extra></extra>","legendgroup":"Moldova","marker":{"color":"#FF6692","size":[0.0],"sizemode":"area","sizeref":0.04903846155,"symbol":"circle"},"mode":"markers","name":"Moldova","orientation":"v","showlegend":true,"x":["Moldova"],"xaxis":"x","y":[0.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=%{x}<br>Tariff=%{marker.size}<extra></extra>","legendgroup":"Nigeria","marker":{"color":"#B6E880","size":[4.730769231],"sizemode":"area","sizeref":0.04903846155,"symbol":"circle"},"mode":"markers","name":"Nigeria","orientation":"v","showlegend":true,"x":["Nigeria"],"xaxis":"x","y":[4.730769231],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=%{x}<br>Tariff=%{marker.size}<extra></extra>","legendgroup":"Tunisia","marker":{"color":"#FF97FF","size":[0.0],"sizemode":"area","sizeref":0.04903846155,"symbol":"circle"},"mode":"markers","name":"Tunisia","orientation":"v","showlegend":true,"x":["Tunisia"],"xaxis":"x","y":[0.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=%{x}<br>Tariff=%{marker.size}<extra></extra>","legendgroup":"Zimbabwe","marker":{"color":"#FECB52","size":[4.557692308],"sizemode":"area","sizeref":0.04903846155,"symbol":"circle"},"mode":"markers","name":"Zimbabwe","orientation":"v","showlegend":true,"x":["Zimbabwe"],"xaxis":"x","y":[4.557692308],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"ba ...

# %% [markdown]
# ### 2017

# %%
dt = data[data['Year'] == 2017]
dt = dt.groupby(['Country']).sum().reset_index()
dt
# Out:
#         Country  Year     Tariff
# 0        Israel  2017   1.033741
# 1        Jordan  2017   7.769231
# 2        Mexico  2017  12.223125
# 3  Saudi Arabia  2017   4.519231
# 4         Sudan  2017  21.865385
# 5    Tajikistan  2017   4.355769
# 6         Yemen  2017   4.596154

# %%
fig = px.scatter(dt, x=dt.Country, y=dt.Tariff, color=dt.Country, size=dt.Tariff)
fig.update_xaxes(title_text = "Country", rangeslider_visible=False, showline=True, linewidth=2, linecolor='black', mirror=True)
fig.update_yaxes(title_text = 'Tariff %', showline=True, linewidth=2, linecolor='black', mirror=True)
fig.update_layout(height=400, width=1000, title_text='Global Tariff % in 2017') 
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="0c0ca8b2-26e4-44ae-bd5b-c9804b257469" class="plotly-graph-div" style="height:400px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0c0ca8b2-26e4-44ae-bd5b-c9804b257469")) {                    Plotly.newPlot(                        "0c0ca8b2-26e4-44ae-bd5b-c9804b257469",                        [{"hovertemplate":"Country=%{x}<br>Tariff=%{marker.size}<extra></extra>","legendgroup":"Israel","marker":{"color":"#636efa","size":[1.033741259],"sizemode":"area","sizeref":0.05466346155,"symbol":"circle"},"mode":"markers","name":"Israel","orientation":"v","showlegend":true,"x":["Israel"],"xaxis":"x","y":[1.033741259],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=%{x}<br>Tariff=%{marker.size}<extra></extra>","legendgroup":"Jordan","marker":{"color":"#EF553B","size":[7.769230769],"sizemode":"area","sizeref":0.05466346155,"symbol":"circle"},"mode":"markers","name":"Jordan","orientation":"v","showlegend":true,"x":["Jordan"],"xaxis":"x","y":[7.769230769],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=%{x}<br>Tariff=%{marker.size}<extra></extra>","legendgroup":"Mexico","marker":{"color":"#00cc96","size":[12.223125],"sizemode":"area","sizeref":0.05466346155,"symbol":"circle"},"mode":"markers","name":"Mexico","orientation":"v","showlegend":true,"x":["Mexico"],"xaxis":"x","y":[12.223125],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=%{x}<br>Tariff=%{marker.size}<extra></extra>","legendgroup":"Saudi Arabia","marker":{"color":"#ab63fa","size":[4.519230769],"sizemode":"area","sizeref":0.05466346155,"symbol":"circle"},"mode":"markers","name":"Saudi Arabia","orientation":"v","showlegend":true,"x":["Saudi Arabia"],"xaxis":"x","y":[4.519230769],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=%{x}<br>Tariff=%{marker.size}<extra></extra>","legendgroup":"Sudan","marker":{"color":"#FFA15A","size":[21.86538462],"sizemode":"area","sizeref":0.05466346155,"symbol":"circle"},"mode":"markers","name":"Sudan","orientation":"v","showlegend":true,"x":["Sudan"],"xaxis":"x","y":[21.86538462],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=%{x}<br>Tariff=%{marker.size}<extra></extra>","legendgroup":"Tajikistan","marker":{"color":"#19d3f3","size":[4.355769231],"sizemode":"area","sizeref":0.05466346155,"symbol":"circle"},"mode":"markers","name":"Tajikistan","orientation":"v","showlegend":true,"x":["Tajikistan"],"xaxis":"x","y":[4.355769231],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=%{x}<br>Tariff=%{marker.size}<extra></extra>","legendgroup":"Yemen","marker":{"color":"#FF6692","size":[4.596153846],"sizemode":"area","sizeref":0.05466346155,"symbol":"circle"},"mode":"markers","name":"Yemen","orientation":"v","showlegend":true,"x":["Yemen"],"xaxis":"x","y":[4.596153846],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.66666666 ...

# %% [markdown]
# ### 2018

# %%
dt = data[data['Year'] == 2018]
dt = dt.groupby(['Country']).sum().reset_index()
dt
# Out:
#                Country  Year     Tariff
# 0          Afghanistan  2018   5.000000
# 1              Bahamas  2018  40.153846
# 2   Dominican Republic  2018   9.769231
# 3             Ethiopia  2018   4.951923
# 4             Honduras  2018   0.000000
# 5              Liberia  2018   4.730769
# 6           Mozambique  2018   7.125000
# 7                Samoa  2018   8.000000
# 8               Serbia  2018   6.906923
# 9          South Korea  2018   0.000000
# 10              Zambia  2018   0.000000

# %%
fig = px.scatter(dt, x=dt.Country, y=dt.Tariff, color=dt.Country, size=dt.Tariff)
fig.update_xaxes(title_text = "Country", rangeslider_visible=False, showline=True, linewidth=2, linecolor='black', mirror=True)
fig.update_yaxes(title_text = 'Tariff %', showline=True, linewidth=2, linecolor='black', mirror=True)
fig.update_layout(height=500, width=1400, title_text='Global Tariff % in 2018') 
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="67446a39-d6a2-45ae-9fe4-3f64f973e991" class="plotly-graph-div" style="height:500px; width:1400px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("67446a39-d6a2-45ae-9fe4-3f64f973e991")) {                    Plotly.newPlot(                        "67446a39-d6a2-45ae-9fe4-3f64f973e991",                        [{"hovertemplate":"Country=%{x}<br>Tariff=%{marker.size}<extra></extra>","legendgroup":"Afghanistan","marker":{"color":"#636efa","size":[5.0],"sizemode":"area","sizeref":0.100384615375,"symbol":"circle"},"mode":"markers","name":"Afghanistan","orientation":"v","showlegend":true,"x":["Afghanistan"],"xaxis":"x","y":[5.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=%{x}<br>Tariff=%{marker.size}<extra></extra>","legendgroup":"Bahamas","marker":{"color":"#EF553B","size":[40.15384615],"sizemode":"area","sizeref":0.100384615375,"symbol":"circle"},"mode":"markers","name":"Bahamas","orientation":"v","showlegend":true,"x":["Bahamas"],"xaxis":"x","y":[40.15384615],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=%{x}<br>Tariff=%{marker.size}<extra></extra>","legendgroup":"Dominican Republic","marker":{"color":"#00cc96","size":[9.769230769],"sizemode":"area","sizeref":0.100384615375,"symbol":"circle"},"mode":"markers","name":"Dominican Republic","orientation":"v","showlegend":true,"x":["Dominican Republic"],"xaxis":"x","y":[9.769230769],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=%{x}<br>Tariff=%{marker.size}<extra></extra>","legendgroup":"Ethiopia","marker":{"color":"#ab63fa","size":[4.951923077],"sizemode":"area","sizeref":0.100384615375,"symbol":"circle"},"mode":"markers","name":"Ethiopia","orientation":"v","showlegend":true,"x":["Ethiopia"],"xaxis":"x","y":[4.951923077],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=%{x}<br>Tariff=%{marker.size}<extra></extra>","legendgroup":"Honduras","marker":{"color":"#FFA15A","size":[0.0],"sizemode":"area","sizeref":0.100384615375,"symbol":"circle"},"mode":"markers","name":"Honduras","orientation":"v","showlegend":true,"x":["Honduras"],"xaxis":"x","y":[0.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=%{x}<br>Tariff=%{marker.size}<extra></extra>","legendgroup":"Liberia","marker":{"color":"#19d3f3","size":[4.730769231],"sizemode":"area","sizeref":0.100384615375,"symbol":"circle"},"mode":"markers","name":"Liberia","orientation":"v","showlegend":true,"x":["Liberia"],"xaxis":"x","y":[4.730769231],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=%{x}<br>Tariff=%{marker.size}<extra></extra>","legendgroup":"Mozambique","marker":{"color":"#FF6692","size":[7.125],"sizemode":"area","sizeref":0.100384615375,"symbol":"circle"},"mode":"markers","name":"Mozambique","orientation":"v","showlegend":true,"x":["Mozambique"],"xaxis":"x","y":[7.125],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=%{x}<br>Tariff=%{marker.size}<extra></extra>","legendgroup":"Samoa","marker":{"color":"#B6E880","size":[8.0],"sizemode":"area","sizeref":0.100384615375,"symbol":"circle"},"mode":"markers","name":"Samoa","orientation":"v","showlegend":true,"x":["Samoa"],"xaxis":"x","y":[8.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=%{x}<br>Tariff=%{marker.size}<extra></extra>","legendgroup":"Serbia","marker":{"color":"#FF97FF","size":[6.906923077],"sizemode":"area","sizeref":0.100384615375,"symbol":"circle"},"mode":"markers","name":"Serbia","orientation":"v","showlegend":true,"x":["Serbia"],"xaxis":"x","y":[6.906923077],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=%{x}<br>Tariff=%{marker.size}<extra></extra>","legendgroup":"South Korea","marker":{"color":"#FECB52","size":[0.0],"sizemode":"area","sizeref":0.100384615375,"symbol":"circle"},"mode":"markers","name":"South Korea","orientation":"v","showlegend":true,"x":[" ...

# %% [markdown]
# ### 2019

# %%
dt = data[data['Year'] == 2019]
dt = dt.groupby(['Country']).sum().reset_index()
dt
# Out:
#                  Country  Year     Tariff
# 0                Albania  2019   0.000000
# 1                Algeria  2019  13.269231
# 2                 Angola  2019  20.000000
# 3               Anguilla  2019  10.000000
# 4    Antigua and Barbuda  2019   4.769231
# ..                   ...   ...        ...
# 142        United States  2019   0.000000
# 143              Uruguay  2019  13.343077
# 144            Venezuela  2019  12.636615
# 145              Vietnam  2019   0.000000
# 146    Wallis and Futuna  2019   4.938462
#
# [147 rows x 3 columns]

# %%
fig = px.scatter(dt, x=dt.Country, y=dt.Tariff, color=dt.Country, size=dt.Tariff)
fig.update_xaxes(title_text = "Country", rangeslider_visible=True, showline=True, linewidth=2, linecolor='black', mirror=True)
fig.update_yaxes(title_text = 'Tariff %', showline=True, linewidth=2, linecolor='black', mirror=True)
fig.update_layout(height=800, width=1400, title_text='Global Tariff % in 2019') 
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="5e4934cd-50bc-467c-bfff-2a3a53f3d951" class="plotly-graph-div" style="height:800px; width:1400px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5e4934cd-50bc-467c-bfff-2a3a53f3d951")) {                    Plotly.newPlot(                        "5e4934cd-50bc-467c-bfff-2a3a53f3d951",                        [{"hovertemplate":"Country=%{x}<br>Tariff=%{marker.size}<extra></extra>","legendgroup":"Albania","marker":{"color":"#636efa","size":[0.0],"sizemode":"area","sizeref":0.0625,"symbol":"circle"},"mode":"markers","name":"Albania","orientation":"v","showlegend":true,"x":["Albania"],"xaxis":"x","y":[0.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=%{x}<br>Tariff=%{marker.size}<extra></extra>","legendgroup":"Algeria","marker":{"color":"#EF553B","size":[13.26923077],"sizemode":"area","sizeref":0.0625,"symbol":"circle"},"mode":"markers","name":"Algeria","orientation":"v","showlegend":true,"x":["Algeria"],"xaxis":"x","y":[13.26923077],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=%{x}<br>Tariff=%{marker.size}<extra></extra>","legendgroup":"Angola","marker":{"color":"#00cc96","size":[20.0],"sizemode":"area","sizeref":0.0625,"symbol":"circle"},"mode":"markers","name":"Angola","orientation":"v","showlegend":true,"x":["Angola"],"xaxis":"x","y":[20.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=%{x}<br>Tariff=%{marker.size}<extra></extra>","legendgroup":"Anguilla","marker":{"color":"#ab63fa","size":[10.0],"sizemode":"area","sizeref":0.0625,"symbol":"circle"},"mode":"markers","name":"Anguilla","orientation":"v","showlegend":true,"x":["Anguilla"],"xaxis":"x","y":[10.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=%{x}<br>Tariff=%{marker.size}<extra></extra>","legendgroup":"Antigua and Barbuda","marker":{"color":"#FFA15A","size":[4.769230769],"sizemode":"area","sizeref":0.0625,"symbol":"circle"},"mode":"markers","name":"Antigua and Barbuda","orientation":"v","showlegend":true,"x":["Antigua and Barbuda"],"xaxis":"x","y":[4.769230769],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=%{x}<br>Tariff=%{marker.size}<extra></extra>","legendgroup":"Argentina","marker":{"color":"#19d3f3","size":[13.45292307],"sizemode":"area","sizeref":0.0625,"symbol":"circle"},"mode":"markers","name":"Argentina","orientation":"v","showlegend":true,"x":["Argentina"],"xaxis":"x","y":[13.45292307],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=%{x}<br>Tariff=%{marker.size}<extra></extra>","legendgroup":"Armenia","marker":{"color":"#FF6692","size":[4.769230769],"sizemode":"area","sizeref":0.0625,"symbol":"circle"},"mode":"markers","name":"Armenia","orientation":"v","showlegend":true,"x":["Armenia"],"xaxis":"x","y":[4.769230769],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=%{x}<br>Tariff=%{marker.size}<extra></extra>","legendgroup":"Aruba","marker":{"color":"#B6E880","size":[6.0],"sizemode":"area","sizeref":0.0625,"symbol":"circle"},"mode":"markers","name":"Aruba","orientation":"v","showlegend":true,"x":["Aruba"],"xaxis":"x","y":[6.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=%{x}<br>Tariff=%{marker.size}<extra></extra>","legendgroup":"Australia","marker":{"color":"#FF97FF","size":[2.044230769],"sizemode":"area","sizeref":0.0625,"symbol":"circle"},"mode":"markers","name":"Australia","orientation":"v","showlegend":true,"x":["Australia"],"xaxis":"x","y":[2.044230769],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=%{x}<br>Tariff=%{marker.size}<extra></extra>","legendgroup":"Austria","marker":{"color":"#FECB52","size":[0.0],"sizemode":"area","sizeref":0.0625,"symbol":"circle"},"mode":"markers","name":"Austria","orientation":"v","showlegend":true,"x":["Austria"],"xaxis":"x","y":[0.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=%{x}<br>T ...
