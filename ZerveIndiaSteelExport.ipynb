# %% [markdown]
# <a href="https://colab.research.google.com/github/Utpal-Mishra/Zerve/blob/main/ZerveIndiaSteelExport.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# DATA SOURCE: https://www.kaggle.com/greeshmagirish/finished-steel-importexport-data-india/version/1

# %% [markdown]
# ### Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import plotly.express as px
import plotly.graph_objects as go
from datetime import datetime as dt

# %% [markdown]
# ### Import Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## **Import Dependencies**

# %% [markdown]
# ### Import File

# %%
import pandas as pd
path = '/content/drive/MyDrive/Jobs/Zerve/Finished_Steel_Export_Categorywise_1.csv'
data = pd.read_csv(path)
print("Data Shape: ", data.shape)
data
# Out:
# Data Shape:  (20, 8)
#                           Category  ... 2017-18
# 0         Non-Alloy Finished Steel  ...    2042
# 1         Non-Alloy Finished Steel  ...     173
# 2         Non-Alloy Finished Steel  ...      43
# 3         Non-Alloy Finished Steel  ...    2258
# 4         Non-Alloy Finished Steel  ...     491
# 5         Non-Alloy Finished Steel  ...    2820
# 6         Non-Alloy Finished Steel  ...      18
# 7         Non-Alloy Finished Steel  ...    1230
# 8         Non-Alloy Finished Steel  ...    1086
# 9         Non-Alloy Finished Steel  ...      58
# 10        Non-Alloy Finished Steel  ...      90
# 11        Non-Alloy Finished Steel  ...      37
# 12        Non-Alloy Finished Steel  ...       2
# 13        Non-Alloy Finished Steel  ...     637
# 14        Non-Alloy Finished Steel  ...    6469
# 15        Non-Alloy Finished Steel  ...    8727
# 16  Alloy/Stainless Finished Steel  ...     523
# 17  Alloy/Stainless Finished Steel  ...     370
# 18  Alloy/Stainless Finished Steel  ...     893
# 19  Total Export of Finished Steel  ...    9620
#
# [20 rows x 8 columns]

# %% [markdown]
# ## **Exploratory Data Analysis**

# %% [markdown]
# ### Check Null Values

# %%
if data.isna().sum().sum() != 0:
  print("EMPTY VALUES EXIST IN THE DATA\n\nFollowing is a list of feature variable with their respective null values count:", data.isna().sum())
# Out:
# EMPTY VALUES EXIST IN THE DATA
#
# Following is a list of feature variable with their respective null values count: Category                                   0
# Sub-Category                               0
# Item - (Export Quantity in '000 Tonnes)    2
# 2013-14                                    1
# 2014-15                                    1
# 2015-16                                    1
# 2016-17                                    1
# 2017-18                                    0
# dtype: int64

# %%
data["Item - (Export Quantity in '000 Tonnes)"] = data["Item - (Export Quantity in '000 Tonnes)"].fillna('Unknown')
data[['2013-14', '2014-15', '2015-16', '2016-17', '2017-18']] = data[['2013-14', '2014-15', '2015-16', '2016-17', '2017-18']].fillna(0)

# %%
if data.isna().sum().sum() != 0:
  print("EMPTY VALUES EXIST IN THE DATA\n\nFollowing is a list of feature variable with their respective null values count:", data.isna().sum())
else:
  print("EMPTY VALUES DOES NOT EXIST IN THE DATA")
# Out:
# EMPTY VALUES DOES NOT EXIST IN THE DATA

# %% [markdown]
# ## **Visualization**

# %% [markdown]
# ### **GROUP BY ITEMS**

# %%
dt = data[["Item - (Export Quantity in '000 Tonnes)", '2013-14', '2014-15', '2015-16', '2016-17', '2017-18']]
dt = dt.melt(id_vars=["Item - (Export Quantity in '000 Tonnes)"], var_name = "Years", value_name = "Production")
dt.sort_values(["Item - (Export Quantity in '000 Tonnes)", 'Years'], inplace = True)
dt
# Out:
#    Item - (Export Quantity in '000 Tonnes)    Years  Production
# 0                              Bars & Rods  2013-14       585.0
# 20                             Bars & Rods  2014-15       392.0
# 40                             Bars & Rods  2015-16       365.0
# 60                             Bars & Rods  2016-17       629.0
# 80                             Bars & Rods  2017-18      2042.0
# ..                                     ...      ...         ...
# 57                                 Unknown  2015-16       439.0
# 76                                 Unknown  2016-17       190.0
# 77                                 Unknown  2016-17       468.0
# 96                                 Unknown  2017-18       523.0
# 97                                 Unknown  2017-18       370.0
#
# [100 rows x 3 columns]

# %%
def barplot(data):
  fig = px.bar(data, x=data["Item - (Export Quantity in '000 Tonnes)"], y=data.Production, animation_frame = data.Years, color=data["Item - (Export Quantity in '000 Tonnes)"])
  fig.update_xaxes(title_text = "Countries", rangeslider_visible=False, showline=True, linewidth=2, linecolor='black', mirror=True)
  fig.update_yaxes(title_text = 'Steel Production (in Tons)', showline=True, linewidth=2, linecolor='black', mirror=True)
  # fig.update_traces(marker_color='rgb(158,202,225)', marker_line_color='rgb(8,48,107)', marker_line_width=1.5, opacity=0.6)
  fig.update_layout(height=700, width=1400, title_text='India Steel Items Production Export (2013-2018)') 
  fig.show()

barplot(dt)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="8d9a2141-5152-4a15-8a4b-4cf2ea40e087" class="plotly-graph-div" style="height:700px; width:1400px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8d9a2141-5152-4a15-8a4b-4cf2ea40e087")) {                    Plotly.newPlot(                        "8d9a2141-5152-4a15-8a4b-4cf2ea40e087",                        [{"alignmentgroup":"True","hovertemplate":"Item - (Export Quantity in '000 Tonnes)=%{x}<br>Years=2013-14<br>Production=%{y}<extra></extra>","legendgroup":"Bars & Rods","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Bars & Rods","offsetgroup":"Bars & Rods","orientation":"v","showlegend":true,"textposition":"auto","x":["Bars & Rods"],"xaxis":"x","y":[585.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Item - (Export Quantity in '000 Tonnes)=%{x}<br>Years=2013-14<br>Production=%{y}<extra></extra>","legendgroup":"CR Coil/Sheets","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"CR Coil/Sheets","offsetgroup":"CR Coil/Sheets","orientation":"v","showlegend":true,"textposition":"auto","x":["CR Coil/Sheets"],"xaxis":"x","y":[561.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Item - (Export Quantity in '000 Tonnes)=%{x}<br>Years=2013-14<br>Production=%{y}<extra></extra>","legendgroup":"Color Coated Sheets/Coils","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Color Coated Sheets/Coils","offsetgroup":"Color Coated Sheets/Coils","orientation":"v","showlegend":true,"textposition":"auto","x":["Color Coated Sheets/Coils"],"xaxis":"x","y":[0.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Item - (Export Quantity in '000 Tonnes)=%{x}<br>Years=2013-14<br>Production=%{y}<extra></extra>","legendgroup":"Electrical Coils/Sheets","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Electrical Coils/Sheets","offsetgroup":"Electrical Coils/Sheets","orientation":"v","showlegend":true,"textposition":"auto","x":["Electrical Coils/Sheets"],"xaxis":"x","y":[10.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Item - (Export Quantity in '000 Tonnes)=%{x}<br>Years=2013-14<br>Production=%{y}<extra></extra>","legendgroup":"GP/GC/Galvalume","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"GP/GC/Galvalume","offsetgroup":"GP/GC/Galvalume","orientation":"v","showlegend":true,"textposition":"auto","x":["GP/GC/Galvalume"],"xaxis":"x","y":[1822.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Item - (Export Quantity in '000 Tonnes)=%{x}<br>Years=2013-14<br>Production=%{y}<extra></extra>","legendgroup":"HR Coil/Strip","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"HR Coil/Strip","offsetgroup":"HR Coil/Strip","orientation":"v","showlegend":true,"textposition":"auto","x":["HR Coil/Strip"],"xaxis":"x","y":[2043.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Item - (Export Quantity in '000 Tonnes)=%{x}<br>Years=2013-14<br>Production=%{y}<extra></extra>","legendgroup":"HR Sheets","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"HR Sheets","offsetgroup":"HR Sheets","orientation":"v","showlegend":true,"textposition":"auto","x":["HR Sheets"],"xaxis":"x","y":[87.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Item - (Export Quantity in '000 Tonnes)=%{x}<br>Years=2013-14<br>Production=%{y}<extra></extra>","legendgroup":"Pipes (Large Diameter)","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Pipes (Large Diameter)","offsetgroup":"Pipes (Large Diameter)","orientation":"v","showlegend":true,"textposition":"auto","x":["Pipes (Large Diameter)"],"xaxis":"x","y":[108.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Item - (Export Quantity in '000 Tonnes)=%{x}<br>Years=2013-14<br>Pr ...

# %%
dt = dt[["Item - (Export Quantity in '000 Tonnes)", 'Production']].groupby("Item - (Export Quantity in '000 Tonnes)").sum()
dt = dt.reset_index()
fig = go.Figure(data=[go.Pie(labels=dt["Item - (Export Quantity in '000 Tonnes)"], values=dt.Production, hole=.5)])
fig.update_layout(height=600, width=1400, title_text='India Steel Items Export Percentage (2013-2018)') 
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="c2e56413-3e18-46c5-b8c7-30463875e40d" class="plotly-graph-div" style="height:600px; width:1400px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c2e56413-3e18-46c5-b8c7-30463875e40d")) {                    Plotly.newPlot(                        "c2e56413-3e18-46c5-b8c7-30463875e40d",                        [{"hole":0.5,"labels":["Bars & Rods","CR Coil/Sheets","Color Coated Sheets/Coils","Electrical Coils/Sheets","GP/GC/Galvalume","HR Coil/Strip","HR Sheets","Pipes (Large Diameter)","Plates","Railway Materials","Structurals","Tin Free Steel","Tin Plates","Total - Alloy/Stainless Finished Steel","Total - Flat Products of Non-Alloy Finished Steel","Total - Non-Alloy Finished Steel","Total - Non-Flat Products of Non-Alloy Finished Steel","Total Export of Finished Steel","Unknown"],"values":[4013.0,4425.0,58.0,174.0,7673.0,9446.0,297.0,1376.0,1772.0,132.0,562.0,6.0,266.0,3321.0,25493.0,30200.0,4707.0,33523.0,3321.0],"type":"pie"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"o ...

# %% [markdown]
# ### **GROUP BY SUB-CATEGORIES**

# %%
dt = data[["Sub-Category", '2013-14', '2014-15', '2015-16', '2016-17', '2017-18']]
dt.groupby(['Sub-Category']).sum().reset_index()
# Out:
#                                         Sub-Category  2013-14  ...  2016-17  2017-18
# 0    Flat Products of Alloy/Stainless Finished Steel    249.0  ...    468.0      370
# 1          Flat Products of Non-Alloy Finished Steel   9714.0  ...  13424.0    12938
# 2  Non-Flat Products of Alloy/Stainless Fnished S...    228.0  ...    190.0      523
# 3      Non-Flat Products of Non-Alloy Finished Steel   1302.0  ...   1744.0     4516
# 4             Total - Alloy/Stainless Finished Steel    477.0  ...    658.0      893
# 5                   Total - Non-Alloy Finished Steel   5508.0  ...   7584.0     8727
# 6                     Total Export of Finished Steel   5985.0  ...   8243.0     9620
#
# [7 rows x 6 columns]

# %%
dt = dt.melt(id_vars=["Sub-Category"], var_name = "Years", value_name = "Production")
dt.sort_values(["Sub-Category", 'Years'], inplace = True)
dt
# Out:
#                                        Sub-Category    Years  Production
# 17  Flat Products of Alloy/Stainless Finished Steel  2013-14       249.0
# 37  Flat Products of Alloy/Stainless Finished Steel  2014-15       353.0
# 57  Flat Products of Alloy/Stainless Finished Steel  2015-16       439.0
# 77  Flat Products of Alloy/Stainless Finished Steel  2016-17       468.0
# 97  Flat Products of Alloy/Stainless Finished Steel  2017-18       370.0
# ..                                              ...      ...         ...
# 19                   Total Export of Finished Steel  2013-14      5985.0
# 39                   Total Export of Finished Steel  2014-15      5596.0
# 59                   Total Export of Finished Steel  2015-16      4079.0
# 79                   Total Export of Finished Steel  2016-17      8243.0
# 99                   Total Export of Finished Steel  2017-18      9620.0
#
# [100 rows x 3 columns]

# %%
def barplot(data):
  fig = px.bar(data, x=data["Sub-Category"], y=data.Production, animation_frame = data.Years, color=data["Sub-Category"])
  fig.update_xaxes(title_text = "Sub-Categories", rangeslider_visible=True, showline=True, linewidth=2, linecolor='black', mirror=True)
  fig.update_yaxes(title_text = 'Steel Production (in Tons)', showline=True, linewidth=2, linecolor='black', mirror=True)
  # fig.update_traces(marker_color='rgb(158,202,225)', marker_line_color='rgb(8,48,107)', marker_line_width=1.5, opacity=0.6)
  fig.update_layout(height=900, width=1400, title_text='India Steel Sub-Category Production Export (2013-2018)') 
  fig.show()

barplot(dt)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="da95b943-90b1-48e9-99b0-ca06707b28e9" class="plotly-graph-div" style="height:900px; width:1400px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("
# 2  Total Export of Finished Steel   5985.0   5596.0   4079.0   8243.0     9620

# %%
dt = dt.melt(id_vars=["Category"], var_name = "Years", value_name = "Production")
dt.sort_values(["Category", 'Years'], inplace = True)
dt
# Out:
#                           Category    Years  Production
# 0   Alloy/Stainless Finished Steel  2013-14       954.0
# 3   Alloy/Stainless Finished Steel  2014-15      1378.0
# 6   Alloy/Stainless Finished Steel  2015-16      1208.0
# 9   Alloy/Stainless Finished Steel  2016-17      1316.0
# 12  Alloy/Stainless Finished Steel  2017-18      1786.0
# 1         Non-Alloy Finished Steel  2013-14     16524.0
# 4         Non-Alloy Finished Steel  2014-15     14718.0
# 7         Non-Alloy Finished Steel  2015-16     10425.0
# 10        Non-Alloy Finished Steel  2016-17     22752.0
# 13        Non-Alloy Finished Steel  2017-18     26181.0
# 2   Total Export of Finished Steel  2013-14      5985.0
# 5   Total Export of Finished Steel  2014-15      5596.0
# 8   Total Export of Finished Steel  2015-16      4079.0
# 11  Total Export of Finished Steel  2016-17      8243.0
# 14  Total Export of Finished Steel  2017-18      9620.0

# %%
def barplot(data):
  fig = px.bar(data, x=data["Category"], y=data.Production, animation_frame = data.Years, color=data["Category"])
  fig.update_xaxes(title_text = "Category", rangeslider_visible=False, showline=True, linewidth=2, linecolor='black', mirror=True)
  fig.update_yaxes(title_text = 'Steel Production (in Tons)', showline=True, linewidth=2, linecolor='black', mirror=True)
  # fig.update_traces(marker_color='rgb(158,202,225)', marker_line_color='rgb(8,48,107)', marker_line_width=1.5, opacity=0.6)
  fig.update_layout(height=500, width=1000, title_text='India Steel Categories Export Percentage (2013-2018)') 
  fig.show()

barplot(dt)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="c1e44490-3ba4-4b5d-88ae-c29af5116f23" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c1e44490-3ba4-4b5d-88ae-c29af5116f23")) {                    Plotly.newPlot(                        "c1e44490-3ba4-4b5d-88ae-c29af5116f23",                        [{"alignmentgroup":"True","hovertemplate":"Category=%{x}<br>Years=2013-14<br>Production=%{y}<extra></extra>","legendgroup":"Alloy/Stainless Finished Steel","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Alloy/Stainless Finished Steel","offsetgroup":"Alloy/Stainless Finished Steel","orientation":"v","showlegend":true,"textposition":"auto","x":["Alloy/Stainless Finished Steel"],"xaxis":"x","y":[954.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Category=%{x}<br>Years=2013-14<br>Production=%{y}<extra></extra>","legendgroup":"Non-Alloy Finished Steel","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Non-Alloy Finished Steel","offsetgroup":"Non-Alloy Finished Steel","orientation":"v","showlegend":true,"textposition":"auto","x":["Non-Alloy Finished Steel"],"xaxis":"x","y":[16524.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Category=%{x}<br>Years=2013-14<br>Production=%{y}<extra></extra>","legendgroup":"Total Export of Finished Steel","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Total Export of Finished Steel","offsetgroup":"Total Export of Finished Steel","orientation":"v","showlegend":true,"textposition":"auto","x":["Total Export of Finished Steel"],"xaxis":"x","y":[5985.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"] ...

# %%
dt = dt[['Category', 'Production']].groupby('Category').sum()
dt = dt.reset_index()
fig = go.Figure(data=[go.Pie(labels=dt.Category, values=dt.Production, hole=.5)])
fig.update_layout(height=600, width=1400, title_text='India Steel Categories Export Percentage') 
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="e61b1ab0-75bf-4e0b-bed0-0ff1a185d6f9" class="plotly-graph-div" style="height:600px; width:1400px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e61b1ab0-75bf-4e0b-bed0-0ff1a185d6f9")) {                    Plotly.newPlot(                        "e61b1ab0-75bf-4e0b-bed0-0ff1a185d6f9",                        [{"hole":0.5,"labels":["Alloy/Stainless Finished Steel","Non-Alloy Finished Steel","Total Export of Finished Steel"],"values":[6642.0,90600.0,33523.0],"type":"pie"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type ...
